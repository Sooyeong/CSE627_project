# %% [markdown]
# # CSE 627 Project 1
# ### House Price: Advanced Regression Techniques
# ### By Sooyeong Lim, Jason Zhao
#
#
#
#
# # Introduction
#
# * Why this competition?
#
#  The Kaggle competition we chose is "House Price: Advanced Regression Techniques". We selected this competition because it satisfies the criterion of good project. Below are few reasons of justification.
#
#  Firstly, we can practice a lot of feature engineering by doing this project. Feature engineering is very important in Data Science. This dataset contains a lot of features(79) with both quantitative variable and categorical variable. Also, there are many missing variables in the dataset and we can practice imputation skills as well.
#
#  Second, This project allow us to use the model we learned from class room including Regularized model and Neural Network based model and we think that it is a good idea to do hands on examples. We went further form this baseline model by adding some Ensnblem model or morden technique- Boosting model
#
#
#
# * Project Timeline and Plan
#
#  Fit the rough model and had a meeting with Dr. Femiani. After the first meeting, we verified that our approach valid and came up alternative ways to fit the model- NN based model fitting. But it turned out that there is some problem in the feature Engineering. Date and meeting time
#
#
#
#
# * Executive Conclusion
#  The fittied model suggest that ~ have a best performance and we ended on
#  First placement-> Second Placement -> Thir Place ment

# %% [markdown]
# ### Index
#
#
# * Exploratory Data Analysis
# * Feature Engineering
# * Modeling
# **1. Regularized model, 2. XGBoost, 3. Neural Network Based Model
# * Results **Provide table of resutls
# * Limitations/Recommendations
# * Reference/Resource

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# [1] Exploratory Data analysis is giving a direction of further analysis. We checked that the overall trend of data distribution and relationship between predictors and response variables and setted properdiretion for the feature engineerning and modeling.

# %%
# Import packages for EDA
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import Imputer
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Import train & test dataset
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')
# How many distinct number of features?
# How many observations?
# Respose variable?

# %% [markdown]
# After importing train&test dataset, we are going to answer following questions to get to know about the problem much better- Feature:0. How many observations do we have? 1. How many number of features in the datset and how many categorical& quantitative features in the data? 2. How dose it look like the response varaible?

# %%
# How many observations do we have? what is concern? 
len(train.index)
len(test.index)
# We have almost equal size of train and test dataset
# Out:
# 1459

# %%
# List of Columns and except SalePrice this 
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# Correlation plot and scatter plot between ~ all features

# %%
cor_mat=train.corr()
f,ax=plt.subplots(figsize=(13,10))
sns.heatmap(cor_mat,vmax=1,square=True)

# %%
#Select top 10 for making prediction

k=10
cols=cor_mat.nlargest(k, 'SalePrice')['SalePrice'].index
cm=np.corrcoef(train[cols].values.T)

sns.set(font_scale=1.25)
hm=sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size':10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
sns.set()
cols=['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(train[cols],size=3)
plt.show()

# %% [markdown]
# #Distribution of Y variable --> Take a log
# *Assumption biolation
#
# Y~ N(XB,$\sigma^{2}$)
#
# Normality assumption check

# %%
sns.distplot(np.log(train['SalePrice']), fit=norm)

# %%
## QQ plot to check Normality assumption

res=stats.probplot(np.log(train['SalePrice']), plot=plt)

# %% [markdown]
# * Explain why noramlity assumtpion is requried

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# [2] A lot of effort in Feature Engineering is needed for this problem. There are many missing observations for the train and test dataset so we imputed by using some trics. We encoded categorical variables. After plotting the dataset that we realized that the relationship between X*Y is not just linear regression. We created seperate Python file to avoid this report lengthy

# %% [markdown]
# * Jason Zhao

# %%
# read test data and training data
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %% [markdown]
# Drop Id, since it is not relevant to the selling price.

# %%
train_data.drop('Id',axis=1,inplace=True)

# %% [markdown]
# Take log of the sales price

# %%
train_data.SalePrice = np.log1p(train_data.SalePrice)

sns.distplot(train_data['SalePrice']);

# %% [markdown]
# Check missing values.

# %%
# check the missing data rate
train_data_na = (train_data.isnull().sum() / len(train_data)) * 100
train_data_na = train_data_na.drop(train_data_na[train_data_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio' :train_data_na})
missing_data
# Out:
#               Missing Ratio
# PoolQC            99.520548
# MiscFeature       96.301370
# Alley             93.767123
# Fence             80.753425
# FireplaceQu       47.260274
# LotFrontage       17.739726
# GarageYrBlt        5.547945
# GarageType         5.547945
# GarageFinish       5.547945
# GarageQual         5.547945
# GarageCond         5.547945
# BsmtFinType2       2.602740
# BsmtExposure       2.602740
# BsmtFinType1       2.534247
# BsmtCond           2.534247
# BsmtQual           2.534247
# MasVnrArea         0.547945
# MasVnrType         0.547945
# Electrical         0.068493

# %% [markdown]
# Based on data description file, we find out most of them are missing is because that house does not have that. Therefore, we will replace those by None

# %%
# PoolQC with NaN means no pool, so we put None instead
train_data.PoolQC = train_data.PoolQC.fillna("None")
test_data.PoolQC = test_data.PoolQC.fillna("None")

# %%
# MiscFeature: Miscellaneous feature not covered in other categories
# NA means None, so we repaced with None
train_data.MiscFeature = train_data.MiscFeature.fillna("None")
test_data.MiscFeature = test_data.MiscFeature.fillna("None")

# %%
# If Alley is NA means there is no Alley access, so we change it to None
train_data.Alley = train_data.Alley.fillna("None")
test_data.Alley = test_data.Alley.fillna("None")

# %%
# If Fence is NA means there is no Fence
train_data.Fence = train_data.Fence.fillna("None")
test_data.Fence = test_data.Fence.fillna("None")

# %%
# If FireplaceQu is NA means there is no Fireplace
train_data.FireplaceQu = train_data.FireplaceQu.fillna("None")
test_data.FireplaceQu = test_data.FireplaceQu.fillna("None")

# %%
# If the house does not have a garage, GarageType GarageFinish GarageQual and GarageCond will be Na
for column in ("GarageType", "GarageFinish", "GarageQual", "GarageCond"):
    train_data[column] = train_data[column].fillna("None")
    test_data[column] = test_data[column] .fillna("None")

# %%
# If there is no basement, BsmtFinType2, BsmtExposure, BsmtFinType1, BsmtCond, BsmtQual will be Na,
for column in ("BsmtFinType2", "BsmtExposure", "BsmtFinType1", "BsmtCond", "BsmtQual"):
    train_data[column] = train_data[column].fillna("None")
    test_data[column] = test_data[column] .fillna("None")

# %%
# Masonry veneer type
train_data.MasVnrType = train_data.MasVnrType.fillna("None")
test_data.MasVnrType = test_data.MasVnrType.fillna("None")

# %%
# since there is no garage, so we will set the year build at 0
train_data.GarageYrBlt = train_data.GarageYrBlt.fillna(0)
test_data.GarageYrBlt = test_data.GarageYrBlt.fillna(0)

# for testing data, GarageArea and GarageCars also has missing vlaue, we set them to 0 because they does not have garage
test_data.GarageArea = test_data.GarageArea.fillna(0)
test_data.GarageCars = test_data.GarageCars.fillna(0)

# %%
train_data["MasVnrArea"] = train_data["MasVnrArea"].fillna(0)
test_data["MasVnrArea"] = test_data['MasVnrArea'].fillna(0)

# %%
test_data["TotalBsmtSF"] = test_data['TotalBsmtSF'].fillna(0)
test_data["BsmtFinSF1"] = test_data['BsmtFinSF1'].fillna(0)
test_data["BsmtFinSF2"] = test_data['BsmtFinSF2'].fillna(0)
test_data["BsmtUnfSF"] = test_data['BsmtUnfSF'].fillna(0)

# %% [markdown]
# After replacing, we check which data are still missing.

# %%
# check the missing data rate
train_data_na = (train_data.isnull().sum() / len(train_data)) * 100
train_data_na = train_data_na.drop(train_data_na[train_data_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio' :train_data_na})
missing_data
# Out:
#              Missing Ratio
# LotFrontage      17.739726
# Electrical        0.068493

# %% [markdown]
# We want to encode every string data to check correlations.

# %%
list(train_data.select_dtypes(exclude=['int', 'float']).columns.values)
# Out:
# ['MSSubClass',
#  'MSZoning',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageCars',
#  'GarageArea',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SaleType',
#  'SaleCondition']

# %%
train_data.MSZoning = train_data.MSZoning.map({'RL':0, 'RM':1, 'FV':2, 'RH':3, 'C (all)':4})
test_data.MSZoning = test_data.MSZoning.map({'RL':0, 'RM':1, 'FV':2, 'RH':3, 'C (all)':4})

# %%
train_data.Street = train_data.Street.map({'Grvl' : 1, 'Pave' : 2})
test_data.Street = test_data.Street.map({'Grvl' : 1, 'Pave' : 2})

# %%
train_data.Alley = train_data.Alley.map({'None':0, 'Grvl' : 1, 'Pave' : 2})
test_data.Alley = test_data.Alley.map({'None':0, 'Grvl' : 1, 'Pave' : 2})

# %%
train_data.LotShape = train_data.LotShape.map({"Reg" : 1, "IR1" : 2, "IR2" : 3, "IR3" : 4})
test_data.LotShape = test_data.LotShape.map({"Reg" : 1, "IR1" : 2, "IR2" : 3, "IR3" : 4})

# %%
train_data.LandContour = train_data.LandContour.map({
    'Lvl' : 1,
    'Bnk' : 2,
    'HLS' : 3,
    'Low' : 4
})
test_data.LandContour = test_data.LandContour.map({
    'Lvl' : 1,
    'Bnk' : 2,
    'HLS' : 3,
    'Low' : 4
})

# %%
train_data.Utilities = train_data.Utilities.map({
    'AllPub' : 1,
    'NoSewr' : 2,
    'NoSeWa' : 3,
    'ELO' :4
})
test_data.Utilities = test_data.Utilities.map({
    'AllPub' : 1,
    'NoSewr' : 2,
    'NoSeWa' : 3,
    'ELO' :4
})

# %%
train_data.LotConfig = train_data.LotConfig.map({
    'Inside' : 1,
    'Corner' : 2,
    'CulDSac' : 3,
    'FR2' : 4,
    'FR3' : 5
})
test_data.LotConfig = test_data.LotConfig.map({
    'Inside' : 1,
    'Corner' : 2,
    'CulDSac' : 3,
    'FR2' : 4,
    'FR3' : 5
})

# %%
train_data.LandSlope = train_data.LandSlope.map({
    'Gtl' : 3,
    'Mod' : 2,
    'Sev' : 1
})
test_data.LandSlope = test_data.LandSlope.map({
    'Gtl' : 3,
    'Mod' : 2,
    'Sev' : 1
})

# %%
Neighborhoodkeys =  train_data.Neighborhood.unique()
NeighborhoodMap = {}
i = 1
for key in Neighborhoodkeys:
    NeighborhoodMap[key] = i
    i += 1

# %%
train_data.Neighborhood = train_data.Neighborhood.map(NeighborhoodMap)
test_data.Neighborhood = test_data.Neighborhood.map(NeighborhoodMap)

# %%
ConditionMap = {'Norm': 3, 'Feedr': 4, 'PosN': 2, 'Artery': 4, 'RRAe': 1, 'RRNn': 1, 'RRAn': 1, 'PosA': 2, 'RRNe': 1}

train_data.Condition1 = train_data.Condition1.map(ConditionMap)
train_data.Condition2 = train_data.Condition2.map(ConditionMap)
test_data.Condition1 = test_data.Condition1.map(ConditionMap)
test_data.Condition2 = test_data.Condition2.map(ConditionMap)

# %%
train_data.BldgType = train_data.BldgType.map({'1Fam': 5, '2FmCon' :4, 'Duplx' :3, 'TwnhsE': 2, 'TwnhsI':1})
test_data.BldgType = test_data.BldgType.map({'1Fam': 5, '2FmCon' :4, 'Duplx' :3, 'TwnhsE': 2, 'TwnhsI':1})

# %%
train_data.HouseStyle = train_data.HouseStyle.map({'2Story': 1, '1Story': 2, '1.5Fin': 3, '1.5Unf': 4, 'SFoyer': 5, 'SLvl': 6, '2.5Unf': 7, '2.5Fin': 8})
test_data.HouseStyle = test_data.HouseStyle.map({'2Story': 1, '1Story': 2, '1.5Fin': 3, '1.5Unf': 4, 'SFoyer': 5, 'SLvl': 6, '2.5Unf': 7, '2.5Fin': 8})

# %%
train_data.RoofStyle = train_data.RoofStyle.map({'Gable': 1, 'Hip': 2, 'Gambrel': 3, 'Mansard': 4, 'Flat': 5, 'Shed': 6})
test_data.RoofStyle = test_data.RoofStyle.map({'Gable': 1, 'Hip': 2, 'Gambrel': 3, 'Mansard': 4, 'Flat': 5, 'Shed': 6})

# %%
train_data.RoofMatl = train_data.RoofMatl.map({'CompShg': 1, 'WdShngl': 2, 'Metal': 3, 'WdShake': 4, 'Membran': 5, 'Tar&Grv': 6, 'Roll': 7, 'ClyTile': 8})
test_data.RoofMatl = test_data.RoofMatl.map({'CompShg': 1, 'WdShngl': 2, 'Metal': 3, 'WdShake': 4, 'Membran': 5, 'Tar&Grv': 6, 'Roll': 7, 'ClyTile': 8})

# %%
ExteriorMap = {'VinylSd': 1, 'MetalSd': 2, 'Wd Sdng': 3, 'HdBoard': 4, 'BrkFace': 5, 'WdShing': 6, 'CemntBd': 7, 'Plywood': 8, 'AsbShng': 9, 'Stucco': 10, 'BrkComm': 11, 'AsphShn': 12, 'Stone': 13, 'ImStucc': 14, 'CBlock': 15}
train_data.Exterior1st = train_data.Exterior1st.map(ExteriorMap)
train_data.Exterior2nd = train_data.Exterior2nd.map(ExteriorMap)
test_data.Exterior1st = test_data.Exterior1st.map(ExteriorMap)
test_data.Exterior2nd = test_data.Exterior2nd.map(ExteriorMap)

# %%
# since has none, so we just samplify this featrue
train_data.MasVnrType = train_data.MasVnrType.map({"BrkCmn" : 1, "BrkFace" : 1, "CBlock" : 1, "Stone" : 1, "None" : 0})
test_data.MasVnrType = test_data.MasVnrType.map({"BrkCmn" : 1, "BrkFace" : 1, "CBlock" : 1, "Stone" : 1, "None" : 0})

# %%
conditionMap = {"None" : 0, "Po" : 1, "Fa" : 2, "TA": 3, "Gd": 4, "Ex" : 5}

# %%
train_data.ExterCond = train_data.ExterCond.map(conditionMap)
test_data.ExterCond = test_data.ExterCond.map(conditionMap)
train_data.ExterQual = train_data.ExterQual.map(conditionMap)
test_data.ExterQual = test_data.ExterQual.map(conditionMap)
train_data.BsmtQual = train_data.BsmtQual.map(conditionMap)
test_data.BsmtQual = test_data.BsmtQual.map(conditionMap)
train_data.BsmtCond = train_data.BsmtCond.map(conditionMap)
test_data.BsmtCond = test_data.BsmtCond.map(conditionMap)
train_data.HeatingQC = train_data.HeatingQC.map(conditionMap)
test_data.HeatingQC = test_data.HeatingQC.map(conditionMap)
train_data.KitchenQual = train_data.KitchenQual.map(conditionMap)
test_data.KitchenQual = test_data.KitchenQual.map(conditionMap)
train_data.FireplaceQu = train_data.FireplaceQu.map(conditionMap)
test_data.FireplaceQu = test_data.FireplaceQu.map(conditionMap)
train_data.GarageQual = train_data.GarageQual.map(conditionMap)
test_data.GarageQual = test_data.GarageQual.map(conditionMap)
train_data.GarageCond = train_data.GarageCond.map(conditionMap)
test_data.GarageCond = test_data.GarageCond.map(conditionMap)
train_data.PoolQC = train_data.PoolQC.map(conditionMap)
test_data.PoolQC = test_data.PoolQC.map(conditionMap)

# %%
train_data.Foundation = train_data.Foundation.map({'PConc': 1, 'CBlock': 2, 'BrkTil': 3, 'Wood': 4, 'Slab': 5, 'Stone': 6})
test_data.Foundation = test_data.Foundation.map({'PConc': 1, 'CBlock': 2, 'BrkTil': 3, 'Wood': 4, 'Slab': 5, 'Stone': 6})

# %%
train_data.BsmtExposure = train_data.BsmtExposure.map({"No" : 0, "Mn" : 1, "Av": 2, "Gd" : 3, "None" : 0})
test_data.BsmtExposure = test_data.BsmtExposure.map({"No" : 0, "Mn" : 1, "Av": 2, "Gd" : 3, "None" : 0})

# %%
BsmtFinTypeMap = {"None" : 0, "Unf" : 1, "LwQ": 2, "Rec" : 3, "BLQ" : 4, "ALQ" : 5, "GLQ" : 6}

# %%
train_data.BsmtFinType1 = train_data.BsmtFinType1.map(BsmtFinTypeMap)
train_data.BsmtFinType2 = train_data.BsmtFinType2.map(BsmtFinTypeMap)
test_data.BsmtFinType1 = test_data.BsmtFinType1.map(BsmtFinTypeMap)
test_data.BsmtFinType2 = test_data.BsmtFinType2.map(BsmtFinTypeMap)

# %%
train_data.Heating = train_data.Heating.map({'GasA': 1, 'GasW': 2, 'Grav': 3, 'Wall': 4, 'OthW': 5, 'Floor': 6})
test_data.Heating = test_data.Heating.map({'GasA': 1, 'GasW': 2, 'Grav': 3, 'Wall': 4, 'OthW': 5, 'Floor': 6})

# %%
train_data.CentralAir = train_data.CentralAir.map({'Y': 1, 'N': 0})
test_data.CentralAir = test_data.CentralAir.map({'Y': 1, 'N': 0})

# %%
train_data.Electrical = train_data.Electrical.map({'SBrkr': 1, 'FuseF': 2, 'FuseA': 3, 'FuseP': 4, 'Mix': 5})
test_data.Electrical = test_data.Electrical.map({'SBrkr': 1, 'FuseF': 2, 'FuseA': 3, 'FuseP': 4, 'Mix': 5})

# %%
train_data.Functional = train_data.Functional.map({'Typ':0, 'Min2':1, 'Min1':2, 'Mod':3, 'Maj1':4, 'Maj2':5, 'Sev':6})
test_data.Functional = test_data.Functional.map({'Typ':0, 'Min2':1, 'Min1':2, 'Mod':3, 'Maj1':4, 'Maj2':5, 'Sev':6})

# %%
train_data.GarageType = train_data.GarageType.map({'Attchd':1, 'Detchd':2, 'BuiltIn':3, 'None':0, 'Basement':4, 'CarPort':5, '2Types':6})
test_data.GarageType = test_data.GarageType.map({'Attchd':1, 'Detchd':2, 'BuiltIn':3, 'None':0, 'Basement':4, 'CarPort':5, '2Types':6})

# %%
train_data.GarageFinish = train_data.GarageFinish.map({'RFn': 1, 'Unf': 2, 'Fin': 3, 'None': 0})
test_data.GarageFinish = test_data.GarageFinish.map({'RFn': 1, 'Unf': 2, 'Fin': 3, 'None': 0})

# %%
train_data.PavedDrive = train_data.PavedDrive.map({'Y':3, 'N':1, 'P':2})
test_data.PavedDrive = test_data.PavedDrive.map({'Y':3, 'N':1, 'P':2})

# %%
train_data.Fence = train_data.Fence.map({'None':0, 'MnPrv':1, 'GdPrv':2, 'GdWo':3, 'MnWw':4})
test_data.Fence = test_data.Fence.map({'None':0, 'MnPrv':1, 'GdPrv':2, 'GdWo':3, 'MnWw':4})

# %%
train_data.MiscFeature = train_data.MiscFeature.map({'None':0, 'Shed':1, 'Othr':2, 'Gar2':3, 'TenC':4})
test_data.MiscFeature = test_data.MiscFeature.map({'None':0, 'Shed':1, 'Othr':2, 'Gar2':3, 'TenC':4})

# %%
train_data.SaleType = train_data.SaleType.map({'WD': 1, 'New': 2, 'COD': 3, 'ConLD': 4, 'ConLI': 5, 'CWD': 6, 'ConLw': 7, 'Con': 8, 'Oth': 9})
test_data.SaleType = test_data.SaleType.map({'WD': 1, 'New': 2, 'COD': 3, 'ConLD': 4, 'ConLI': 5, 'CWD': 6, 'ConLw': 7, 'Con': 8, 'Oth': 9})

# %%
train_data.SaleCondition = train_data.SaleCondition.map({'Normal': 1, 'Abnorml': 2, 'Partial': 3, 'AdjLand': 4, 'Alloca': 5, 'Family': 6})
test_data.SaleCondition = test_data.SaleCondition.map({'Normal': 1, 'Abnorml': 2, 'Partial': 3, 'AdjLand': 4, 'Alloca': 5, 'Family': 6})

# %% [markdown]
# After enconding, all of features' datatype has became int or float.

# %% [markdown]
# We tried to inpute those missing value, but after inpute, all datatype has bcame float which cause more problem, so we just chose to fill those data by mean value.

# %%
# train_data=train_data.fillna(train_data.median())
# test_data=test_data.fillna(test_data.median())

# %%
correlated = train_data.corr()
correlated = correlated.loc['SalePrice']
correlated = correlated.sort_values(ascending=False)

print(correlated.head(15))
# Out:
# SalePrice       1.000000
# OverallQual     0.817185
# GrLivArea       0.700927
# GarageCars      0.680625
# ExterQual       0.678840
# KitchenQual     0.667893
# GarageArea      0.650888
# BsmtQual        0.615804
# TotalBsmtSF     0.612134
# 1stFlrSF        0.596981
# FullBath        0.594771
# YearBuilt       0.586570
# YearRemodAdd    0.565608
# FireplaceQu     0.546362
# TotRmsAbvGrd    0.534422
# Name: SalePrice, dtype: float64
# 0        7
# 1        6
# 2        7
# 3        7
# 4        8
# 5        5
# 6        8
# 7        7
# 8        7
# 9        5
# 10       5
# 11       9
# 12       5
# 13       7
# 14       6
# 15       7
# 16       6
# 17       4
# 18       5
# 19       5
# 20       8
# 21       7
# 22       8
# 23       5
# 24       5
# 25       8
# 26       5
# 27       8
# 28       5
# 29       4
#         ..
# 1430     5
# 1431     6
# 1432     4
# 1433     6
# 1434     5
# 1435     6
# 1436     4
# 1437     8
# 1438     6
# 1439     7
# 1440     6
# 1441     6
# 1442    10
# 1443     6
# 1444     7
# 1445     6
# 1446     5
# 1447     8
# 1448     4
# 1449     5
# 1450     5
# 1451     8
# 1452     5
# 1453     5
# 1454     7
# 1455     6
# 1456     6
# 1457     7
# 1458     5
# 1459     5
# Name: OverallQual, Length: 1460, dtype: int64

# %%
from sklearn import linear_model

# %%
dfImpute = train_data.loc[:, ['1stFlrSF', 'LotArea', 'LotArea_log', 'LotFrontage']].copy()
testIx = dfImpute.loc[:,'LotFrontage'].isnull()

# %%
# check the missing data rate
train_data_na = (train_data.isnull().sum() / len(train_data)) * 100
train_data_na = train_data_na.drop(train_data_na[train_data_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio' :train_data_na})
missing_data
# Out:
#              Missing Ratio
# LotFrontage      17.739726
# BldgType          8.630137
# Exterior2nd       7.260274
# GarageType        1.301370
# Electrical        0.068493

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso
import warnings
import seaborn as sns
from scipy.stats import skew
from scipy.stats.stats import pearsonr
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.linear_model import Ridge, RidgeCV, ElasticNet, LassoCV, LassoLarsCV
from sklearn.model_selection import cross_val_score
from operator import itemgetter
import itertools
import xgboost as xgb

# %%
## Try different feature engineering with our model

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

all_data = pd.concat((train.loc[:,'MSSubClass':'SaleCondition'], test.loc[:,'MSSubClass':'SaleCondition']), ignore_index=True)

warnings.simplefilter('ignore', np.RankWarning)

x = all_data.loc[np.logical_not(all_data["LotFrontage"].isnull()), "LotArea"]
y = all_data.loc[np.logical_not(all_data["LotFrontage"].isnull()), "LotFrontage"]

t = (x <= 25000) & (y <= 150)

p = np.polyfit(x[t], y[t], 1)

all_data.loc[all_data['LotFrontage'].isnull(), 'LotFrontage'] = np.polyval(p, all_data.loc[all_data['LotFrontage'].isnull(), 'LotArea'])

all_data = all_data.fillna({
    'Alley' : 'NoAlley',
    'MasVnrType': 'None',
    'FireplaceQu': 'NoFireplace',
    'GarageType': 'NoGarage',
    'GarageFinish': 'NoGarage',
    'GarageQual': 'NoGarage',
    'GarageCond': 'NoGarage',
    'BsmtFullBath': 0,
    'BsmtHalfBath': 0,
    'BsmtQual' : 'NoBsmt',
    'BsmtCond' : 'NoBsmt',
    'BsmtExposure' : 'NoBsmt',
    'BsmtFinType1' : 'NoBsmt',
    'BsmtFinType2' : 'NoBsmt',
    'KitchenQual' : 'TA',
    'MSZoning' : 'RL',
    'Utilities' : 'AllPub',
    'Exterior1st' : 'VinylSd',
    'Exterior2nd'   : 'VinylSd',
    'Functional' : 'Typ',
    'PoolQC' : 'NoPool',
    'Fence' : 'NoFence',
    'MiscFeature' : 'None',
    'Electrical' : 'SBrkr'

})

#all_data.loc[all_data.SaleCondition.isnull(), 'SaleCondition'] = 'Normal'

#all_data.loc[all_data.SaleCondition.isnull(), 'SaleType'] = 'WD'

all_data.loc[all_data.MasVnrType == 'None', 'MasVnrArea'] = 0

all_data.loc[all_data.BsmtFinType1=='NoBsmt', 'BsmtFinSF1'] = 0

all_data.loc[all_data.BsmtFinType2=='NoBsmt', 'BsmtFinSF2'] = 0

#all_data.loc[all_data.BsmtFinSF1.isnull(), 'BsmtFinSF1'] = all_data.BsmtFinSF1.median()

all_data.loc[all_data.BsmtQual=='NoBsmt', 'BsmtUnfSF'] = 0

#all_data.loc[all_data.BsmtUnfSF.isnull(), 'BsmtUnfSF'] = all_data.BsmtUnfSF.median()

all_data.loc[all_data.BsmtQual=='NoBsmt', 'TotalBsmtSF'] = 0

#all_data.loc[all_data['GarageArea'].isnull(), 'GarageArea'] = all_data.loc[all_data['GarageType']=='Detchd', 'GarageArea'].mean()

#all_data.loc[all_data['GarageCars'].isnull(), 'GarageCars'] = all_data.loc[all_data['GarageType']=='Detchd', 'GarageCars'].median()

all_data = all_data.replace({'Utilities': {'AllPub': 1, 'NoSeWa': 0, 'NoSewr': 0, 'ELO': 0},

                             'Street': {'Pave': 1, 'Grvl': 0 },

                             'FireplaceQu': {'Ex': 5,

                                            'Gd': 4,

                                            'TA': 3,

                                            'Fa': 2,

                                            'Po': 1,

                                            'NoFireplace': 0

                                            },

                             'Fence': {'GdPrv': 2,

                                       'GdWo': 2,

                                       'MnPrv': 1,

                                       'MnWw': 1,

                                       'NoFence': 0},

                             'ExterQual': {'Ex': 5,

                                            'Gd': 4,

                                            'TA': 3,

                                            'Fa': 2,

                                            'Po': 1

                                            },

                             'ExterCond': {'Ex': 5,

                                            'Gd': 4,

                                            'TA': 3,

                                            'Fa': 2,

                                            'Po': 1

                                            },

                             'BsmtQual': {'Ex': 5,

                                            'Gd': 4,

                                            'TA': 3,

                                            'Fa': 2,

                                            'Po': 1,

                                            'NoBsmt': 0},

                             'BsmtExposure': {'Gd': 3,

                                            'Av': 2,

                                            'Mn': 1,

                                            'No': 0,

                                            'NoBsmt': 0},

                             'BsmtCond': {'Ex': 5,

                                            'Gd': 4,

                                            'TA': 3,

                                            'Fa': 2,

                                            'Po': 1,

                                            'NoBsmt': 0},

                             'GarageQual': {'Ex': 5,

                                            'Gd': 4,

                                            'TA': 3,

                                            'Fa': 2,

                                            'Po': 1,

                                            'NoGarage': 0},

                             'GarageCond': {'Ex': 5,

                                            'Gd': 4,

                                            'TA': 3,

                                            'Fa': 2,

                                            'Po': 1,

                                            'NoGarage': 0},

                             'KitchenQual': {'Ex': 5,

                                            'Gd': 4,

                                            'TA': 3,

                                            'Fa': 2,

                                            'Po': 1},

                             'Functional': {'Typ': 0,

                                            'Min1': 1,

                                            'Min2': 1,

                                            'Mod': 2,

                                            'Maj1': 3,

                                            'Maj2': 4,

                                            'Sev': 5,

                                            'Sal': 6},

                             'CentralAir': {'Y': 1,

                                            'N': 0},
                            
                              'PavedDrive': {'Y': 1,

                                            'P': 0,

                                            'N': 0}
                            
                            })


newer_dwelling = all_data.MSSubClass.replace({20: 1,

                                            30: 0,

                                            40: 0,

                                            45: 0,

                                            50: 0,

                                            60: 1,

                                            70: 0,

                                            75: 0,

                                            80: 0,

                                            85: 0,

                                            90: 0,

                                           120: 1,

                                           150: 0,

                                           160: 0,

                                           180: 0,

                                           190: 0})

newer_dwelling.name = 'newer_dwelling'

all_data = all_data.replace({'MSSubClass': {20: 'SubClass_20',

                                            30: 'SubClass_30',

                                            40: 'SubClass_40',

                                            45: 'SubClass_45',

                                            50: 'SubClass_50',

                                            60: 'SubClass_60',

                                            70: 'SubClass_70',

                                            75: 'SubClass_75',

                                            80: 'SubClass_80',

                                            85: 'SubClass_85',

                                            90: 'SubClass_90',

                                           120: 'SubClass_120',

                                           150: 'SubClass_150',

                                           160: 'SubClass_160',

                                           180: 'SubClass_180',

                                           190: 'SubClass_190'}})

overall_poor_qu = all_data.OverallQual.copy()

overall_poor_qu = 5 - overall_poor_qu

overall_poor_qu[overall_poor_qu<0] = 0

overall_poor_qu.name = 'overall_poor_qu'

overall_good_qu = all_data.OverallQual.copy()

overall_good_qu = overall_good_qu - 5

overall_good_qu[overall_good_qu<0] = 0

overall_good_qu.name = 'overall_good_qu'

overall_poor_cond = all_data.OverallCond.copy()

overall_poor_cond = 5 - overall_poor_cond

overall_poor_cond[overall_poor_cond<0] = 0

overall_poor_cond.name = 'overall_poor_cond'

overall_good_cond = all_data.OverallCond.copy()

overall_good_cond = overall_good_cond - 5

overall_good_cond[overall_good_cond<0] = 0

overall_good_cond.name = 'overall_good_cond'

exter_poor_qu = all_data.ExterQual.copy()

exter_poor_qu[exter_poor_qu<3] = 1

exter_poor_qu[exter_poor_qu>=3] = 0

exter_poor_qu.name = 'exter_poor_qu'

exter_good_qu = all_data.ExterQual.copy()

exter_good_qu[exter_good_qu<=3] = 0

exter_good_qu[exter_good_qu>3] = 1

exter_good_qu.name = 'exter_good_qu'

exter_poor_cond = all_data.ExterCond.copy()

exter_poor_cond[exter_poor_cond<3] = 1

exter_poor_cond[exter_poor_cond>=3] = 0

exter_poor_cond.name = 'exter_poor_cond'

exter_good_cond = all_data.ExterCond.copy()

exter_good_cond[exter_good_cond<=3] = 0

exter_good_cond[exter_good_cond>3] = 1

exter_good_cond.name = 'exter_good_cond'

bsmt_poor_cond = all_data.BsmtCond.copy()

bsmt_poor_cond[bsmt_poor_cond<3] = 1

bsmt_poor_cond[bsmt_poor_cond>=3] = 0

bsmt_poor_cond.name = 'bsmt_poor_cond'

bsmt_good_cond = all_data.BsmtCond.copy()

bsmt_good_cond[bsmt_good_cond<=3] = 0

bsmt_good_cond[bsmt_good_cond>3] = 1

bsmt_good_cond.name = 'bsmt_good_cond'

garage_poor_qu = all_data.GarageQual.copy()

garage_poor_qu[garage_poor_qu<3] = 1

garage_poor_qu[garage_poor_qu>=3] = 0

garage_poor_qu.name = 'garage_poor_qu'

garage_good_qu = all_data.GarageQual.copy()

garage_good_qu[garage_good_qu<=3] = 0

garage_good_qu[garage_good_qu>3] = 1

garage_good_qu.name = 'garage_good_qu'

garage_poor_cond = all_data.GarageCond.copy()

garage_poor_cond[garage_poor_cond<3] = 1

garage_poor_cond[garage_poor_cond>=3] = 0

garage_poor_cond.name = 'garage_poor_cond'

garage_good_cond = all_data.GarageCond.copy()

garage_good_cond[garage_good_cond<=3] = 0

garage_good_cond[garage_good_cond>3] = 1

garage_good_cond.name = 'garage_good_cond'

kitchen_poor_qu = all_data.KitchenQual.copy()

kitchen_poor_qu[kitchen_poor_qu<3] = 1

kitchen_poor_qu[kitchen_poor_qu>=3] = 0

kitchen_poor_qu.name = 'kitchen_poor_qu'

kitchen_good_qu = all_data.KitchenQual.copy()

kitchen_good_qu[kitchen_good_qu<=3] = 0

kitchen_good_qu[kitchen_good_qu>3] = 1

kitchen_good_qu.name = 'kitchen_good_qu'

qu_list = pd.concat((overall_poor_qu, overall_good_qu, overall_poor_cond, overall_good_cond, exter_poor_qu,

                     exter_good_qu, exter_poor_cond, exter_good_cond, bsmt_poor_cond, bsmt_good_cond, garage_poor_qu,

                     garage_good_qu, garage_poor_cond, garage_good_cond, kitchen_poor_qu, kitchen_good_qu), axis=1)

bad_heating = all_data.HeatingQC.replace({'Ex': 0,

                                          'Gd': 0,

                                          'TA': 0,

                                          'Fa': 1,

                                          'Po': 1})

bad_heating.name = 'bad_heating'

MasVnrType_Any = all_data.MasVnrType.replace({'BrkCmn': 1,

                                              'BrkFace': 1,

                                              'CBlock': 1,

                                              'Stone': 1,

                                              'None': 0})

MasVnrType_Any.name = 'MasVnrType_Any'

SaleCondition_PriceDown = all_data.SaleCondition.replace({'Abnorml': 1,

                                                          'Alloca': 1,

                                                          'AdjLand': 1,

                                                          'Family': 1,

                                                          'Normal': 0,

                                                          'Partial': 0})

SaleCondition_PriceDown.name = 'SaleCondition_PriceDown'

Neighborhood_Good = pd.DataFrame(np.zeros((all_data.shape[0],1)), columns=['Neighborhood_Good'])

Neighborhood_Good[all_data.Neighborhood=='NridgHt'] = 1

Neighborhood_Good[all_data.Neighborhood=='Crawfor'] = 1

Neighborhood_Good[all_data.Neighborhood=='StoneBr'] = 1

Neighborhood_Good[all_data.Neighborhood=='Somerst'] = 1

Neighborhood_Good[all_data.Neighborhood=='NoRidge'] = 1

from sklearn.svm import SVC

svm = SVC(C=100, gamma=0.0001, kernel='rbf')

pc = pd.Series(np.zeros(train.shape[0]))

pc[:] = 'pc1'

pc[train.SalePrice >= 150000] = 'pc2'

pc[train.SalePrice >= 220000] = 'pc3'

columns_for_pc = ['Exterior1st', 'Exterior2nd', 'RoofMatl', 'Condition1', 'Condition2', 'BldgType']

X_t = pd.get_dummies(train.loc[:, columns_for_pc], sparse=True)

svm.fit(X_t, pc) #Training

pc_pred = svm.predict(X_t)

p = train.SalePrice/100000

price_category = pd.DataFrame(np.zeros((all_data.shape[0],1)), columns=['pc'])

X_t = pd.get_dummies(all_data.loc[:, columns_for_pc], sparse=True)

pc_pred = svm.predict(X_t)

price_category[pc_pred=='pc2'] = 1

price_category[pc_pred=='pc3'] = 2

price_category = price_category.to_sparse()

season = all_data.MoSold.replace( {1: 0,

                                   2: 0,

                                   3: 0,

                                   4: 1,

                                   5: 1,

                                   6: 1,

                                   7: 1,

                                   8: 0,

                                   9: 0,

                                  10: 0,

                                  11: 0,

                                  12: 0})

season.name = 'season'

all_data = all_data.replace({'MoSold': {1: 'Yan',

                                        2: 'Feb',

                                        3: 'Mar',

                                        4: 'Apr',

                                        5: 'May',

                                        6: 'Jun',

                                        7: 'Jul',

                                        8: 'Avg',

                                        9: 'Sep',

                                        10: 'Oct',

                                        11: 'Nov',

                                        12: 'Dec'}})

reconstruct = pd.DataFrame(np.zeros((all_data.shape[0],1)), columns=['Reconstruct'])

reconstruct[all_data.YrSold < all_data.YearRemodAdd] = 1

reconstruct = reconstruct.to_sparse()

recon_after_buy = pd.DataFrame(np.zeros((all_data.shape[0],1)), columns=['ReconstructAfterBuy'])

recon_after_buy[all_data.YearRemodAdd >= all_data.YrSold] = 1

recon_after_buy = recon_after_buy.to_sparse()

build_eq_buy = pd.DataFrame(np.zeros((all_data.shape[0],1)), columns=['Build.eq.Buy'])

build_eq_buy[all_data.YearBuilt >= all_data.YrSold] = 1

build_eq_buy = build_eq_buy.to_sparse()

all_data.YrSold = 2010 - all_data.YrSold

year_map = pd.concat(pd.Series('YearGroup' + str(i+1), index=range(1871+i*20,1891+i*20)) for i in range(0, 7))

all_data.GarageYrBlt = all_data.GarageYrBlt.map(year_map)

all_data.loc[all_data['GarageYrBlt'].isnull(), 'GarageYrBlt'] = 'NoGarage'

all_data.YearBuilt = all_data.YearBuilt.map(year_map)

all_data.YearRemodAdd = all_data.YearRemodAdd.map(year_map)

numeric_feats = all_data.dtypes[all_data.dtypes != "object"].index

t = all_data[numeric_feats].quantile(.75)

use_75_scater = t[t != 0].index

all_data[use_75_scater] = all_data[use_75_scater]/all_data[use_75_scater].quantile(.75)

t = ['LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',

     '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',

     'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal']

all_data.loc[:, t] = np.log1p(all_data.loc[:, t])

train["SalePrice"] = np.log1p(train["SalePrice"])

X = pd.get_dummies(all_data)

X = X.fillna(X.mean())

X = X.drop('RoofMatl_ClyTile', axis=1)

X = X.drop('Condition2_PosN', axis=1)

X = X.drop('MSZoning_C (all)', axis=1)

X = X.drop('MSSubClass_SubClass_160', axis=1)

X = pd.concat((X, newer_dwelling, season, reconstruct, recon_after_buy,

               qu_list, bad_heating, MasVnrType_Any, price_category, build_eq_buy), axis=1)

from itertools import product, chain

def poly(X):

    areas = ['LotArea', 'TotalBsmtSF', 'GrLivArea', 'GarageArea', 'BsmtUnfSF']

    t = chain(qu_list.axes[1].get_values(),

              ['OverallQual', 'OverallCond', 'ExterQual', 'ExterCond', 'BsmtCond', 'GarageQual', 'GarageCond',

               'KitchenQual', 'HeatingQC', 'bad_heating', 'MasVnrType_Any', 'SaleCondition_PriceDown', 'Reconstruct',

               'ReconstructAfterBuy', 'Build.eq.Buy'])

    for a, t in product(areas, t):

        x = X.loc[:, [a, t]].prod(1)

        x.name = a + '_' + t

        yield x

XP = pd.concat(poly(X), axis=1)

X = pd.concat((X, XP), axis=1)

train_X = X[:train.shape[0]]

test_X = X[train.shape[0]:]

y = train.SalePrice

outliers_id = np.array([523,1298])
##Remove outliers
train_X = X_train.drop(outliers_id)

y = y.drop(outliers_id)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-128-cc753fea19eb> in <module>()
#     648 outliers_id = np.array([523,1298])
#     649 ##Remove outliers
# --> 650 train_X = X_train.drop(outliers_id)
#     651
#     652 y = y.drop(outliers_id)
#
# ~\Anaconda3\envs\CSE627\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\envs\CSE627\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# ~\Anaconda3\envs\CSE627\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# ~\Anaconda3\envs\CSE627\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: '[ 523 1298] not found in axis'

# %%
# Out:
# (1458, 466)

# %%
##Temporarlily model fitting


clf1 = Lasso(alpha = 0.0002)

clf1.fit(X_train, y)

lasso_preds = np.expm1(clf1.predict(X_test))

#ELASTIC NET

clf2 = ElasticNet(alpha=0.0004, l1_ratio=1.2)

clf2.fit(X_train, y)

elas_preds = np.expm1(clf2.predict(X_test))

#XGBOOST

clf3=xgb.XGBRegressor(colsample_bytree=0.4,

                 gamma=0.045,

                 learning_rate=0.07,

                 max_depth=10,

                 min_child_weight=1.5,

                 n_estimators=300,

                 reg_alpha=0.65,

                 reg_lambda=0.45,

                 subsample=0.95)



clf3.fit(X_train, y)

xgb_preds = np.expm1(clf3.predict(X_test))

# %% [markdown]
# ### Modeling

# %% [markdown]
# [3] Firstly, we fitted Regularized Linear model by using Ridge regression (L2) Regularization and checked it's performance. And tried to apply Elastic net which is ensenble model of L1(Lasso) regression with L2. After fitting this regression file, we also used Neural Network based model by using Pytorch
# Firt trial, Second trial, Third Trial.. Feature engineering again, Grid search

# %%
# Import needed libaries
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import SVR, LinearSVR
from sklearn.linear_model import ElasticNet, SGDRegressor, BayesianRidge
from sklearn.kernel_ridge import KernelRidge

# %%
#Get labels by select SalePrice
y_log=train_data['SalePrice']
train_data.drop('SalePrice',axis=1,inplace=True)

# %%
from sklearn.model_selection import cross_val_score, train_test_split

# %%
# Partition the dataset in test + validation sets
X_train, X_test, y_train, y_test = train_test_split(train_X, y, test_size = 0.3, random_state = 0)
print("X_train : " + str(X_train.shape))
print("X_test : " + str(X_test.shape))
print("y_train : " + str(y_train.shape))
print("y_test : " + str(y_test.shape))
#Define 70% is used as testing data and 30% is test dataset.
# Out:
# X_train : (1022, 466)
# X_test : (438, 466)
# y_train : (1022,)
# y_test : (438,)

# %% [markdown]
# ### Lasso regression

# %%
clf1 = Lasso(alpha = 0.0002)
clf1.fit(X_train, y_train)

lasso_preds = np.expm1(clf1.predict(test_X))

# %% [markdown]
# ## xgboost

# %%
import xgboost

# %%
# Create an xgboost model with leaning rate 0.05


                 
model_xgb = xgboost.XGBRegressor( colsample_bytree=0.4,gamma=0.045,n_estimators=2000, learning_rate=0.02,subsample=0.95,reg_alpha=0.65,reg_lambda=0.45)

# %%
# Training
model_xgb.fit(X_train, y_train, early_stopping_rounds=10, eval_set=[(X_test, y_test)])
# Out:
# [0]	validation_0-rmse:11.3045
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:11.0788
# [2]	validation_0-rmse:10.8578
# [3]	validation_0-rmse:10.6412
# [4]	validation_0-rmse:10.4289
# [5]	validation_0-rmse:10.2208
# [6]	validation_0-rmse:10.0168
# [7]	validation_0-rmse:9.81688
# [8]	validation_0-rmse:9.62099
# [9]	validation_0-rmse:9.42891
# [10]	validation_0-rmse:9.24054
# [11]	validation_0-rmse:9.05596
# [12]	validation_0-rmse:8.87503
# [13]	validation_0-rmse:8.69808
# [14]	validation_0-rmse:8.52445
# [15]	validation_0-rmse:8.35417
# [16]	validation_0-rmse:8.18734
# [17]	validation_0-rmse:8.02394
# [18]	validation_0-rmse:7.86397
# [19]	validation_0-rmse:7.70704
# [20]	validation_0-rmse:7.5532
# [21]	validation_0-rmse:7.40234
# [22]	validation_0-rmse:7.25463
# [23]	validation_0-rmse:7.10996
# [24]	validation_0-rmse:6.96815
# [25]	validation_0-rmse:6.829
# [26]	validation_0-rmse:6.69276
# [27]	validation_0-rmse:6.55923
# [28]	validation_0-rmse:6.42842
# [29]	validation_0-rmse:6.30026
# [30]	validation_0-rmse:6.17459
# [31]	validation_0-rmse:6.05129
# [32]	validation_0-rmse:5.93057
# [33]	validation_0-rmse:5.81229
# [34]	validation_0-rmse:5.69649
# [35]	validation_0-rmse:5.58298
# [36]	validation_0-rmse:5.47183
# [37]	validation_0-rmse:5.36287
# [38]	validation_0-rmse:5.25593
# [39]	validation_0-rmse:5.15115
# [40]	validation_0-rmse:5.04848
# [41]	validation_0-rmse:4.94779
# [42]	validation_0-rmse:4.84913
# [43]	validation_0-rmse:4.75263
# [44]	validation_0-rmse:4.65791
# [45]	validation_0-rmse:4.56519
# [46]	validation_0-rmse:4.47426
# [47]	validation_0-rmse:4.38497
# [48]	validation_0-rmse:4.29791
# [49]	validation_0-rmse:4.21245
# [50]	validation_0-rmse:4.12862
# [51]	validation_0-rmse:4.04659
# [52]	validation_0-rmse:3.96618
# [53]	validation_0-rmse:3.88708
# [54]	validation_0-rmse:3.80963
# [55]	validation_0-rmse:3.73403
# [56]	validation_0-rmse:3.65952
# [57]	validation_0-rmse:3.58678
# [58]	validation_0-rmse:3.51565
# [59]	validation_0-rmse:3.44577
# [60]	validation_0-rmse:3.37712
# [61]	validation_0-rmse:3.31022
# [62]	validation_0-rmse:3.2445
# [63]	validation_0-rmse:3.17979
# [64]	validation_0-rmse:3.11678
# [65]	validation_0-rmse:3.05492
# [66]	validation_0-rmse:2.99402
# [67]	validation_0-rmse:2.93476
# [68]	validation_0-rmse:2.87637
# [69]	validation_0-rmse:2.81909
# [70]	validation_0-rmse:2.76308
# [71]	validation_0-rmse:2.70836
# [72]	validation_0-rmse:2.65461
# [73]	validation_0-rmse:2.60191
# [74]	validation_0-rmse:2.55035
# [75]	validation_0-rmse:2.49992
# [76]	validation_0-rmse:2.45056
# [77]	validation_0-rmse:2.4019
# [78]	validation_0-rmse:2.35443
# [79]	validation_0-rmse:2.30768
# [80]	validation_0-rmse:2.26193
# [81]	validation_0-rmse:2.21719
# [82]	validation_0-rmse:2.17338
# [83]	validation_0-rmse:2.13045
# [84]	validation_0-rmse:2.08821
# [85]	validation_0-rmse:2.04708
# [86]	validation_0-rmse:2.00654
# [87]	validation_0-rmse:1.96677
# [88]	validation_0-rmse:1.92779
# [89]	validation_0-rmse:1.88965
# [90]	validation_0-rmse:1.85241
# [91]	validation_0-rmse:1.81581
# [92]	validation_0-rmse:1.77986
# [93]	validation_0-rmse:1.74453
# [94]	validation_0-rmse:1.71007
# [95]	validation_0-rmse:1.67618
# [96]	validation_0-rmse:1.64303
# [97]	validation_0-rmse:1.61064
# [98]	validation_0-rmse:1.57888
# [99]	validation_0-rmse:1.54769
# [100]	validation_0-rmse:1.51715
# [101]	validation_0-rmse:1.48737
# [102]	validation_0-rmse:1.45803
# [103]	validation_0-rmse:1.42937
# [104]	validation_0-rmse:1.40126
# [105]	validation_0-rmse:1.37349
# [106]	validation_0-rmse:1.34641
# [107]	validation_0-rmse:1.32
# [108]	validation_0-rmse:1.29405
# [109]	validation_0-rmse:1.26873
# [110]	validation_0-rmse:1.24387
# [111]	validation_0-rmse:1.21945
# [112]	validation_0-rmse:1.19549
# [113]	validation_0-rmse:1.17212
# [114]	validation_0-rmse:1.14931
# [115]	validation_0-rmse:1.12667
# [116]	validation_0-rmse:1.1047
# [117]	validation_0-rmse:1.08325
# [118]	validation_0-rmse:1.06222
# [119]	validation_0-rmse:1.0414
# [120]	validation_0-rmse:1.02134
# [121]	validation_0-rmse:1.00144
# [122]	validation_0-rmse:0.982285
# [123]	validation_0-rmse:0.963275
# [124]	validation_0-rmse:0.944635
# [125]	validation_0-rmse:0.926451
# [126]	validation_0-rmse:0.908589
# [127]	validation_0-rmse:0.891127
# [128]	validation_0-rmse:0.87384
# [129]	validation_0-rmse:0.857005
# [130]	validation_0-rmse:0.840414
# [131]	validation_0-rmse:0.824314
# [132]	validation_0-rmse:0.808554
# [133]	validation_0-rmse:0.793121
# [134]	validation_0-rmse:0.777889
# [135]	validation_0-rmse:0.763089
# [136]	validation_0-rmse:0.748496
# [137]	validation_0-rmse:0.734353
# [138]	validation_0-rmse:0.720607
# [139]	validation_0-rmse:0.706818
# [140]	validation_0-rmse:0.693558
# [141]	validation_0-rmse:0.680618
# [142]	validation_0-rmse:0.667671
# [143]	validation_0-rmse:0.655092
# [144]	validation_0-rmse:0.642713
# [145]	validation_0-rmse:0.630716
# [146]	validation_0-rmse:0.619029
# [147]	validation_0-rmse:0.607343
# [148]	validation_0-rmse:0.596016
# [149]	validation_0-rmse:0.584909
# [150]	validation_0-rmse:0.574149
# [151]	validation_0-rmse:0.563671
# [152]	validation_0-rmse:0.553477
# [153]	validation_0-rmse:0.543334
# [154]	validation_0-rmse:0.533337
# [155]	validation_0-rmse:0.523508
# [156]	validation_0-rmse:0.514007
# [157]	validation_0-rmse:0.504888
# [158]	validation_0-rmse:0.495994
# [159]	validation_0-rmse:0.487062
# [160]	validation_0-rmse:0.478408
# [161]	validation_0-rmse:0.469876
# [162]	validation_0-rmse:0.461671
# [163]	validation_0-rmse:0.45343
# [164]	validation_0-rmse:0.445487
# [165]	validation_0-rmse:0.437698
# [166]	validation_0-rmse:0.430042
# [167]	validation_0-rmse:0.422482
# [168]	validation_0-rmse:0.415199
# [169]	validation_0-rmse:0.407969
# [170]	validation_0-rmse:0.400934
# [171]	validation_0-rmse:0.39398
# [172]	validation_0-rmse:0.387282
# [173]	validation_0-rmse:0.380699
# [174]	validation_0-rmse:0.374348
# [175]	validation_0-rmse:0.368134
# [176]	validation_0-rmse:0.361992
# [177]	validation_0-rmse:0.356012
# [178]	validation_0-rmse:0.350084
# [179]	validation_0-rmse:0.344397
# [180]	validation_0-rmse:0.338838
# [181]	validation_0-rmse:0.333355
# [182]	validation_0-rmse:0.327991
# [183]	validation_0-rmse:0.322767
# [184]	validation_0-rmse:0.31765
# [185]	validation_0-rmse:0.31274
# [186]	validation_0-rmse:0.307944
# [187]	validation_0-rmse:0.303135
# [188]	validation_0-rmse:0.298459
# [189]	validation_0-rmse:0.293979
# [190]	validation_0-rmse:0.28963
# [191]	validation_0-rmse:0.285249
# [192]	validation_0-rmse:0.281032
# [193]	validation_0-rmse:0.277006
# [194]	validation_0-rmse:0.273134
# [195]	validation_0-rmse:0.269309
# [196]	validation_0-rmse:0.265551
# [197]	validation_0-rmse:0.261844
# [198]	validation_0-rmse:0.258243
# [199]	validation_0-rmse:0.254676
# [200]	validation_0-rmse:0.251347
# [201]	validation_0-rmse:0.247961
# [202]	validation_0-rmse:0.24471
# [203]	validation_0-rmse:0.241524
# [204]	validation_0-rmse:0.238416
# [205]	validation_0-rmse:0.235418
# [206]	validation_0-rmse:0.232412
# [207]	validation_0-rmse:0.229576
# [208]	validation_0-rmse:0.226732
# [209]	validation_0-rmse:0.223977
# [210]	validation_0-rmse:0.221304
# [211]	validation_0-rmse:0.218687
# [212]	validation_0-rmse:0.216195
# [213]	validation_0-rmse:0.213738
# [214]	validation_0-rmse:0.211388
# [215]	validation_0-rmse:0.208948
# [216]	validation_0-rmse:0.206577
# [217]	validation_0-rmse:0.204435
# [218]	validation_0-rmse:0.202237
# [219]	validation_0-rmse:0.20017
# [220]	validation_0-rmse:0.198125
# [221]	validation_0-rmse:0.196128
# [222]	validation_0-rmse:0.1942
# [223]	validation_0-rmse:0.192279
# [224]	validation_0-rmse:0.190584
# [225]	validation_0-rmse:0.188797
# [226]	validation_0-rmse:0.187079
# [227]	validation_0-rmse:0.185371
# [228]	validation_0-rmse:0.183736
# [229]	validation_0-rmse:0.182182
# [230]	validation_0-rmse:0.180657
# [231]	validation_0-rmse:0.17922
# [232]	validation_0-rmse:0.177801
# [233]	validation_0-rmse:0.176333
# [234]	validation_0-rmse:0.174966
# [235]	validation_0-rmse:0.173688
# [236]	validation_0-rmse:0.172437
# [237]	validation_0-rmse:0.171123
# [238]	validation_0-rmse:0.169875
# [239]	validation_0-rmse:0.168744
# [240]	validation_0-rmse:0.16763
# [241]	validation_0-rmse:0.166538
# [242]	validation_0-rmse:0.165445
# [243]	validation_0-rmse:0.164424
# [244]	validation_0-rmse:0.163376
# [245]	validation_0-rmse:0.162377
# [246]	validation_0-rmse:0.161426
# [247]	validation_0-rmse:0.160522
# [248]	validation_0-rmse:0.159631
# [249]	validation_0-rmse:0.158759
# [250]	validation_0-rmse:0.157951
# [251]	validation_0-rmse:0.157136
# [252]	validation_0-rmse:0.15632
# [253]	validation_0-rmse:0.155537
# [254]	validation_0-rmse:0.154767
# [255]	validation_0-rmse:0.154075
# [256]	validation_0-rmse:0.153374
# [257]	validation_0-rmse:0.152667
# [258]	validation_0-rmse:0.152082
# [259]	validation_0-rmse:0.151456
# [260]	validation_0-rmse:0.150828
# [261]	validation_0-rmse:0.150225
# [262]	validation_0-rmse:0.149624
# [263]	validation_0-rmse:0.149045
# [264]	validation_0-rmse:0.148595
# [265]	validation_0-rmse:0.148085
# [266]	validation_0-rmse:0.147552
# [267]	validation_0-rmse:0.147033
# [268]	validation_0-rmse:0.146539
# [269]	validation_0-rmse:0.146066
# [270]	validation_0-rmse:0.145698
# [271]	validation_0-rmse:0.145254
# [272]	validation_0-rmse:0.144855
# [273]	validation_0-rmse:0.144512
# [274]	validation_0-rmse:0.144155
# [275]	validation_0-rmse:0.143805
# [276]	validation_0-rmse:0.143497
# [277]	validation_0-rmse:0.14314
# [278]	validation_0-rmse:0.142758
# [279]	validation_0-rmse:0.142426
# [280]	validation_0-rmse:0.142083
# [281]	validation_0-rmse:0.141807
# [282]	validation_0-rmse:0.141473
# [283]	validation_0-rmse:0.141157
# [284]	validation_0-rmse:0.140919
# [285]	validation_0-rmse:0.140678
# [286]	validation_0-rmse:0.140393
# [287]	validation_0-rmse:0.140225
# [288]	validation_0-rmse:0.139995
# [289]	validation_0-rmse:0.139744
# [290]	validation_0-rmse:0.139526
# [291]	validation_0-rmse:0.139342
# [292]	validation_0-rmse:0.139174
# [293]	validation_0-rmse:0.138986
# [294]	validation_0-rmse:0.138794
# [295]	validation_0-rmse:0.138624
# [296]	validation_0-rmse:0.138397
# [297]	validation_0-rmse:0.138226
# [298]	validation_0-rmse:0.138042
# [299]	validation_0-rmse:0.137921
# [300]	validation_0-rmse:0.137779
# [301]	validation_0-rmse:0.13758
# [302]	validation_0-rmse:0.137427
# [303]	validation_0-rmse:0.13725
# [304]	validation_0-rmse:0.137093
# [305]	validation_0-rmse:0.13696
# [306]	validation_0-rmse:0.136791
# [307]	validation_0-rmse:0.136622
# [308]	validation_0-rmse:0.136474
# [309]	validation_0-rmse:0.136327
# [310]	validation_0-rmse:0.136159
# [311]	validation_0-rmse:0.136079
# [312]	validation_0-rmse:0.135962
# [313]	validation_0-rmse:0.135868
# [314]	validation_0-rmse:0.135787
# [315]	validation_0-rmse:0.135678
# [316]	validation_0-rmse:0.135575
# [317]	validation_0-rmse:0.135463
# [318]	validation_0-rmse:0.135365
# [319]	validation_0-rmse:0.135282
# [320]	validation_0-rmse:0.135199
# [321]	validation_0-rmse:0.135089
# [322]	validation_0-rmse:0.135018
# [323]	validation_0-rmse:0.134884
# [324]	validation_0-rmse:0.134804
# [325]	validation_0-rmse:0.134696
# [326]	validation_0-rmse:0.134601
# [327]	validation_0-rmse:0.134507
# [328]	validation_0-rmse:0.13443
# [329]	validation_0-rmse:0.134333
# [330]	validation_0-rmse:0.134254
# [331]	validation_0-rmse:0.134144
# [332]	validation_0-rmse:0.13408
# [333]	validation_0-rmse:0.134045
# [334]	validation_0-rmse:0.133982
# [335]	validation_0-rmse:0.133952
# [336]	validation_0-rmse:0.133881
# [337]	validation_0-rmse:0.133798
# [338]	validation_0-rmse:0.133738
# [339]	validation_0-rmse:0.13371
# [340]	validation_0-rmse:0.133681
# [341]	validation_0-rmse:0.133661
# [342]	validation_0-rmse:0.133631
# [343]	validation_0-rmse:0.133573
# [344]	validation_0-rmse:0.133545
# [345]	validation_0-rmse:0.133474
# [346]	validation_0-rmse:0.133403
# [347]	validation_0-rmse:0.133388
# [348]	validation_0-rmse:0.133312
# [349]	validation_0-rmse:0.133248
# [350]	validation_0-rmse:0.133232
# [351]	validation_0-rmse:0.133211
# [352]	validation_0-rmse:0.133165
# [353]	validation_0-rmse:0.133134
# [354]	validation_0-rmse:0.133106
# [355]	validation_0-rmse:0.133072
# [356]	validation_0-rmse:0.133042
# [357]	validation_0-rmse:0.133014
# [358]	validation_0-rmse:0.133003
# [359]	validation_0-rmse:0.132974
# [360]	validation_0-rmse:0.132961
# [361]	validation_0-rmse:0.132915
# [362]	validation_0-rmse:0.132888
# [363]	validation_0-rmse:0.132795
# [364]	validation_0-rmse:0.132761
# [365]	validation_0-rmse:0.132732
# [366]	validation_0-rmse:0.132648
# [367]	validation_0-rmse:0.132596
# [368]	validation_0-rmse:0.132555
# [369]	validation_0-rmse:0.132516
# [370]	validation_0-rmse:0.132517
# [371]	validation_0-rmse:0.132473
# [372]	validation_0-rmse:0.132434
# [373]	validation_0-rmse:0.132396
# [374]	validation_0-rmse:0.132332
# [375]	validation_0-rmse:0.132274
# [376]	validation_0-rmse:0.13223
# [377]	validation_0-rmse:0.132183
# [378]	validation_0-rmse:0.132165
# [379]	validation_0-rmse:0.132132
# [380]	validation_0-rmse:0.132114
# [381]	validation_0-rmse:0.132084
# [382]	validation_0-rmse:0.13206
# [383]	validation_0-rmse:0.132031
# [384]	validation_0-rmse:0.132001
# [385]	validation_0-rmse:0.131974
# [386]	validation_0-rmse:0.131919
# [387]	validation_0-rmse:0.131917
# [388]	validation_0-rmse:0.131873
# [389]	validation_0-rmse:0.131807
# [390]	validation_0-rmse:0.131779
# [391]	validation_0-rmse:0.131747
# [392]	validation_0-rmse:0.131711
# [393]	validation_0-rmse:0.131658
# [394]	validation_0-rmse:0.131657
# [395]	validation_0-rmse:0.13162
# [396]	validation_0-rmse:0.131582
# [397]	validation_0-rmse:0.1316
# [398]	validation_0-rmse:0.131582
# [399]	validation_0-rmse:0.131527
# [400]	validation_0-rmse:0.131512
# [401]	validation_0-rmse:0.131483
# [402]	validation_0-rmse:0.131459
# [403]	validation_0-rmse:0.13145
# [404]	validation_0-rmse:0.131435
# [405]	validation_0-rmse:0.131429
# [406]	validation_0-rmse:0.131418
# [407]	validation_0-rmse:0.131411
# [408]	validation_0-rmse:0.131407
# [409]	validation_0-rmse:0.131413
# [410]	validation_0-rmse:0.131379
# [411]	validation_0-rmse:0.131348
# [412]	validation_0-rmse:0.131346
# [413]	validation_0-rmse:0.131324
# [414]	validation_0-rmse:0.131263
# [415]	validation_0-rmse:0.131244
# [416]	validation_0-rmse:0.131207
# [417]	validation_0-rmse:0.131143
# [418]	validation_0-rmse:0.131137
# [419]	validation_0-rmse:0.131119
# [420]	validation_0-rmse:0.131107
# [421]	validation_0-rmse:0.131084
# [422]	validation_0-rmse:0.131074
# [423]	validation_0-rmse:0.131092
# [424]	validation_0-rmse:0.131088
# [425]	validation_0-rmse:0.131091
# [426]	validation_0-rmse:0.131116
# [427]	validation_0-rmse:0.131074
# [428]	validation_0-rmse:0.131048
# [429]	validation_0-rmse:0.131036
# [430]	validation_0-rmse:0.131007
# [431]	validation_0-rmse:0.130998
# [432]	validation_0-rmse:0.130964
# [433]	validation_0-rmse:0.130929
# [434]	validation_0-rmse:0.13087
# [435]	validation_0-rmse:0.130869
# [436]	validation_0-rmse:0.130841
# [437]	validation_0-rmse:0.130831
# [438]	validation_0-rmse:0.130823
# [439]	validation_0-rmse:0.130803
# [440]	validation_0-rmse:0.130811
# [441]	validation_0-rmse:0.130808
# [442]	validation_0-rmse:0.13078
# [443]	validation_0-rmse:0.130767
# [444]	validation_0-rmse:0.130735
# [445]	validation_0-rmse:0.130733
# [446]	validation_0-rmse:0.130745
# [447]	validation_0-rmse:0.130736
# [448]	validation_0-rmse:0.130734
# [449]	validation_0-rmse:0.130732
# [450]	validation_0-rmse:0.130717
# [451]	validation_0-rmse:0.130693
# [452]	validation_0-rmse:0.130663
# [453]	validation_0-rmse:0.130664
# [454]	validation_0-rmse:0.130627
# [455]	validation_0-rmse:0.130627
# [456]	validation_0-rmse:0.13059
# [457]	validation_0-rmse:0.130567
# [458]	validation_0-rmse:0.130564
# [459]	validation_0-rmse:0.130559
# [460]	validation_0-rmse:0.130559
# [461]	validation_0-rmse:0.130547
# [462]	validation_0-rmse:0.13053
# [463]	validation_0-rmse:0.13053
# [464]	validation_0-rmse:0.130528
# [465]	validation_0-rmse:0.130528
# [466]	validation_0-rmse:0.13052
# [467]	validation_0-rmse:0.13052
# [468]	validation_0-rmse:0.130519
# [469]	validation_0-rmse:0.1305
# [470]	validation_0-rmse:0.130507
# [471]	validation_0-rmse:0.130499
# [472]	validation_0-rmse:0.130498
# [473]	validation_0-rmse:0.13049
# [474]	validation_0-rmse:0.130471
# [475]	validation_0-rmse:0.130448
# [476]	validation_0-rmse:0.13044
# [477]	validation_0-rmse:0.130409
# [478]	validation_0-rmse:0.130397
# [479]	validation_0-rmse:0.13037
# [480]	validation_0-rmse:0.130375
# [481]	validation_0-rmse:0.130353
# [482]	validation_0-rmse:0.130361
# [483]	validation_0-rmse:0.130344
# [484]	validation_0-rmse:0.130365
# [485]	validation_0-rmse:0.130351
# [486]	validation_0-rmse:0.130336
# [487]	validation_0-rmse:0.130333
# [488]	validation_0-rmse:0.130317
# [489]	validation_0-rmse:0.130281
# [490]	validation_0-rmse:0.130289
# [491]	validation_0-rmse:0.130289
# [492]	validation_0-rmse:0.130307
# [493]	validation_0-rmse:0.13027
# [494]	validation_0-rmse:0.130257
# [495]	validation_0-rmse:0.130254
# [496]	validation_0-rmse:0.130237
# [497]	validation_0-rmse:0.130236
# [498]	validation_0-rmse:0.130236
# [499]	validation_0-rmse:0.130209
# [500]	validation_0-rmse:0.13021
# [501]	validation_0-rmse:0.130224
# [502]	validation_0-rmse:0.130219
# [503]	validation_0-rmse:0.130177
# [504]	validation_0-rmse:0.130177
# [505]	validation_0-rmse:0.130177
# [506]	validation_0-rmse:0.130177
# [507]	validation_0-rmse:0.130154
# [508]	validation_0-rmse:0.130154
# [509]	validation_0-rmse:0.130167
# [510]	validation_0-rmse:0.130167
# [511]	validation_0-rmse:0.130161
# [512]	validation_0-rmse:0.13016
# [513]	validation_0-rmse:0.130173
# [514]	validation_0-rmse:0.130173
# [515]	validation_0-rmse:0.13015
# [516]	validation_0-rmse:0.13015
# [517]	validation_0-rmse:0.13015
# [518]	validation_0-rmse:0.130131
# [519]	validation_0-rmse:0.130071
# [520]	validation_0-rmse:0.130071
# [521]	validation_0-rmse:0.1301
# [522]	validation_0-rmse:0.1301
# [523]	validation_0-rmse:0.1301
# [524]	validation_0-rmse:0.1301
# [525]	validation_0-rmse:0.130073
# [526]	validation_0-rmse:0.130073
# [527]	validation_0-rmse:0.130055
# [528]	validation_0-rmse:0.130055
# [529]	validation_0-rmse:0.130012
# [530]	validation_0-rmse:0.13
# [531]	validation_0-rmse:0.13
# [532]	validation_0-rmse:0.12999
# [533]	validation_0-rmse:0.12999
# [534]	validation_0-rmse:0.129987
# [535]	validation_0-rmse:0.129974
# [536]	validation_0-rmse:0.129974
# [537]	validation_0-rmse:0.129973
# [538]	validation_0-rmse:0.129973
# [539]	validation_0-rmse:0.129981
# [540]	validation_0-rmse:0.12998
# [541]	validation_0-rmse:0.12998
# [542]	validation_0-rmse:0.12998
# [543]	validation_0-rmse:0.12998
# [544]	validation_0-rmse:0.129957
# [545]	validation_0-rmse:0.129957
# [546]	validation_0-rmse:0.129939
# [547]	validation_0-rmse:0.129934
# [548]	validation_0-rmse:0.129923
# [549]	validation_0-rmse:0.129909
# [550]	validation_0-rmse:0.129909
# [551]	validation_0-rmse:0.129916
# [552]	validation_0-rmse:0.129901
# [553]	validation_0-rmse:0.129874
# [554]	validation_0-rmse:0.129874
# [555]	validation_0-rmse:0.129874
# [556]	validation_0-rmse:0.129874
# [557]	validation_0-rmse:0.129874
# [558]	validation_0-rmse:0.129874
# [559]	validation_0-rmse:0.129865
# [560]	validation_0-rmse:0.129865
# [561]	validation_0-rmse:0.129865
# [562]	validation_0-rmse:0.129864
# [563]	validation_0-rmse:0.129833
# [564]	validation_0-rmse:0.129833
# [565]	validation_0-rmse:0.129838
# [566]	validation_0-rmse:0.129837
# [567]	validation_0-rmse:0.129837
# [568]	validation_0-rmse:0.129837
# [569]	validation_0-rmse:0.129837
# [570]	validation_0-rmse:0.129836
# [571]	validation_0-rmse:0.129835
# [572]	validation_0-rmse:0.129832
# [573]	validation_0-rmse:0.129829
# [574]	validation_0-rmse:0.129829
# [575]	validation_0-rmse:0.129829
# [576]	validation_0-rmse:0.129842
# [577]	validation_0-rmse:0.129842
# [578]	validation_0-rmse:0.129842
# [579]	validation_0-rmse:0.129842
# [580]	validation_0-rmse:0.129832
# [581]	validation_0-rmse:0.12983
# [582]	validation_0-rmse:0.129819
# [583]	validation_0-rmse:0.1298
# [584]	validation_0-rmse:0.1298
# [585]	validation_0-rmse:0.129804
# [586]	validation_0-rmse:0.129785
# [587]	validation_0-rmse:0.129785
# [588]	validation_0-rmse:0.129785
# [589]	validation_0-rmse:0.129785
# [590]	validation_0-rmse:0.129784
# [591]	validation_0-rmse:0.12974
# [592]	validation_0-rmse:0.129724
# [593]	validation_0-rmse:0.129724
# [594]	validation_0-rmse:0.129709
# [595]	validation_0-rmse:0.129709
# [596]	validation_0-rmse:0.129709
# [597]	validation_0-rmse:0.129709
# [598]	validation_0-rmse:0.129709
# [599]	validation_0-rmse:0.129709
# [600]	validation_0-rmse:0.129709
# [601]	validation_0-rmse:0.129709
# [602]	validation_0-rmse:0.1297
# [603]	validation_0-rmse:0.1297
# [604]	validation_0-rmse:0.12969
# [605]	validation_0-rmse:0.129689
# [606]	validation_0-rmse:0.129689
# [607]	validation_0-rmse:0.129689
# [608]	validation_0-rmse:0.129689
# [609]	validation_0-rmse:0.129689
# [610]	validation_0-rmse:0.129701
# [611]	validation_0-rmse:0.129701
# [612]	validation_0-rmse:0.129665
# [613]	validation_0-rmse:0.129665
# [614]	validation_0-rmse:0.129665
# [615]	validation_0-rmse:0.129665
# [616]	validation_0-rmse:0.129639
# [617]	validation_0-rmse:0.129639
# [618]	validation_0-rmse:0.129639
# [619]	validation_0-rmse:0.129639
# [620]	validation_0-rmse:0.129639
# [621]	validation_0-rmse:0.129607
# [622]	validation_0-rmse:0.129607
# [623]	validation_0-rmse:0.129606
# [624]	validation_0-rmse:0.129594
# [625]	validation_0-rmse:0.12957
# [626]	validation_0-rmse:0.12957
# [627]	validation_0-rmse:0.12957
# [628]	validation_0-rmse:0.12957
# [629]	validation_0-rmse:0.129563
# [630]	validation_0-rmse:0.129563
# [631]	validation_0-rmse:0.129563
# [632]	validation_0-rmse:0.129563
# [633]	validation_0-rmse:0.129563
# [634]	validation_0-rmse:0.129563
# [635]	validation_0-rmse:0.129563
# [636]	validation_0-rmse:0.129543
# [637]	validation_0-rmse:0.129543
# [638]	validation_0-rmse:0.129543
# [639]	validation_0-rmse:0.129543
# [640]	validation_0-rmse:0.129533
# [641]	validation_0-rmse:0.129536
# [642]	validation_0-rmse:0.129513
# [643]	validation_0-rmse:0.129513
# [644]	validation_0-rmse:0.129513
# [645]	validation_0-rmse:0.129513
# [646]	validation_0-rmse:0.129513
# [647]	validation_0-rmse:0.129513
# [648]	validation_0-rmse:0.129511
# [649]	validation_0-rmse:0.129511
# [650]	validation_0-rmse:0.129511
# [651]	validation_0-rmse:0.129511
# [652]	validation_0-rmse:0.129511
# [653]	validation_0-rmse:0.12951
# [654]	validation_0-rmse:0.129493
# [655]	validation_0-rmse:0.129493
# [656]	validation_0-rmse:0.129474
# [657]	validation_0-rmse:0.129453
# [658]	validation_0-rmse:0.129441
# [659]	validation_0-rmse:0.129441
# [660]	validation_0-rmse:0.129441
# [661]	validation_0-rmse:0.12944
# [662]	validation_0-rmse:0.12944
# [663]	validation_0-rmse:0.129446
# [664]	validation_0-rmse:0.129446
# [665]	validation_0-rmse:0.129423
# [666]	validation_0-rmse:0.129422
# [667]	validation_0-rmse:0.129408
# [668]	validation_0-rmse:0.129408
# [669]	validation_0-rmse:0.129406
# [670]	validation_0-rmse:0.129386
# [671]	validation_0-rmse:0.129386
# [672]	validation_0-rmse:0.129386
# [673]	validation_0-rmse:0.129386
# [674]	validation_0-rmse:0.129341
# [675]	validation_0-rmse:0.129334
# [676]	validation_0-rmse:0.129334
# [677]	validation_0-rmse:0.129334
# [678]	validation_0-rmse:0.129334
# [679]	validation_0-rmse:0.129334
# [680]	validation_0-rmse:0.129315
# [681]	validation_0-rmse:0.129315
# [682]	validation_0-rmse:0.129315
# [683]	validation_0-rmse:0.129314
# [684]	validation_0-rmse:0.129314
# [685]	validation_0-rmse:0.129314
# [686]	validation_0-rmse:0.129314
# [687]	validation_0-rmse:0.129284
# [688]	validation_0-rmse:0.129284
# [689]	validation_0-rmse:0.129284
# [690]	validation_0-rmse:0.129284
# [691]	validation_0-rmse:0.129284
# [692]	validation_0-rmse:0.129245
# [693]	validation_0-rmse:0.129246
# [694]	validation_0-rmse:0.129246
# [695]	validation_0-rmse:0.129245
# [696]	validation_0-rmse:0.129245
# [697]	validation_0-rmse:0.129246
# [698]	validation_0-rmse:0.129232
# [699]	validation_0-rmse:0.129232
# [700]	validation_0-rmse:0.129232
# [701]	validation_0-rmse:0.129229
# [702]	validation_0-rmse:0.129229
# [703]	validation_0-rmse:0.129229
# [704]	validation_0-rmse:0.129229
# [705]	validation_0-rmse:0.129229
# [706]	validation_0-rmse:0.129229
# [707]	validation_0-rmse:0.129229
# [708]	validation_0-rmse:0.129197
# [709]	validation_0-rmse:0.129174
# [710]	validation_0-rmse:0.129174
# [711]	validation_0-rmse:0.129153
# [712]	validation_0-rmse:0.129153
# [713]	validation_0-rmse:0.129153
# [714]	validation_0-rmse:0.129153
# [715]	validation_0-rmse:0.129153
# [716]	validation_0-rmse:0.129152
# [717]	validation_0-rmse:0.129153
# [718]	validation_0-rmse:0.129153
# [719]	validation_0-rmse:0.129153
# [720]	validation_0-rmse:0.129153
# [721]	validation_0-rmse:0.129153
# [722]	validation_0-rmse:0.129153
# [723]	validation_0-rmse:0.129162
# [724]	validation_0-rmse:0.129162
# [725]	validation_0-rmse:0.129162
# [726]	validation_0-rmse:0.129162
# Stopping. Best iteration:
# [716]	validation_0-rmse:0.129152
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.4, gamma=0.045, learning_rate=0.02,
#        max_delta_step=0, max_depth=3, min_child_weight=1, missing=None,
#        n_estimators=2000, n_jobs=1, nthread=None, objective='reg:linear',
#        random_state=0, reg_alpha=0.65, reg_lambda=0.45, scale_pos_weight=1,
#        seed=None, silent=True, subsample=0.95)

# %%
y_test_xgb_ela = model_xgb.predict(X_test)

# %% [markdown]
# ### Keras

# %%
import keras

# %%
seed = 7
np.random.seed(seed)

# %%
# Create a model and add layers
kerasModel = keras.models.Sequential()

kerasModel.add(keras.layers.Dense(500, input_dim = X_train.shape[1],activation='relu'))
kerasModel.add(keras.layers.Dense(400,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(300,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(200,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(100,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(50,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(300,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(200,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(100,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(300,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(200,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(100,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(50,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(300,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(200,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(50,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(25,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(12,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(6,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(25,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(12,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(6,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(3,kernel_initializer='normal',activation='relu'))
kerasModel.add(keras.layers.Dense(1,kernel_initializer='normal'))
kerasModel.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 500)               233500
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               200400
# _________________________________________________________________
# dense_3 (Dense)              (None, 300)               120300
# _________________________________________________________________
# dense_4 (Dense)              (None, 200)               60200
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_6 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_7 (Dense)              (None, 300)               15300
# _________________________________________________________________
# dense_8 (Dense)              (None, 200)               60200
# _________________________________________________________________
# dense_9 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_10 (Dense)             (None, 300)               30300
# _________________________________________________________________
# dense_11 (Dense)             (None, 200)               60200
# _________________________________________________________________
# dense_12 (Dense)             (None, 100)               20100
# _________________________________________________________________
# dense_13 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_14 (Dense)             (None, 300)               15300
# _________________________________________________________________
# dense_15 (Dense)             (None, 200)               60200
# _________________________________________________________________
# dense_16 (Dense)             (None, 50)                10050
# _________________________________________________________________
# dense_17 (Dense)             (None, 25)                1275
# _________________________________________________________________
# dense_18 (Dense)             (None, 12)                312
# _________________________________________________________________
# dense_19 (Dense)             (None, 6)                 78
# _________________________________________________________________
# dense_20 (Dense)             (None, 25)                175
# _________________________________________________________________
# dense_21 (Dense)             (None, 12)                312
# _________________________________________________________________
# dense_22 (Dense)             (None, 6)                 78
# _________________________________________________________________
# dense_23 (Dense)             (None, 3)                 21
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 4
# =================================================================
# Total params: 938,605
# Trainable params: 938,605
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Number of layer searching method ==> Grid search can be used

# %%
# Define another loss function
from keras import backend as K
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1))

# %%
# Set loss function and optimizer
kerasModel.compile(loss = 'mse', optimizer = "adam")

# %%
# Set callback function which will ealystop when val_loss does not become better in 50 epochs
# save the best model
callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', patience=50),
            keras.callbacks.ModelCheckpoint('best.h5', monitor='val_loss', save_best_only=True, mode='min')]

# %%
## Train
history = kerasModel.fit(X_train, y_train, epochs=200, validation_data = (X_test, y_test))
# Out:
# Train on 1020 samples, validate on 438 samples
# Epoch 1/200
# 1020/1020 [==============================] - 1s 753us/step - loss: 0.0843 - val_loss: 0.0490
# Epoch 2/200
# 1020/1020 [==============================] - 1s 850us/step - loss: 0.0778 - val_loss: 0.0284
# Epoch 3/200
# 1020/1020 [==============================] - 1s 867us/step - loss: 0.0097 - val_loss: 0.0788
# Epoch 4/200
# 1020/1020 [==============================] - 1s 811us/step - loss: 0.0121 - val_loss: 0.0656
# Epoch 5/200
# 1020/1020 [==============================] - 1s 828us/step - loss: 0.0205 - val_loss: 0.0245
# Epoch 6/200
# 1020/1020 [==============================] - 1s 770us/step - loss: 0.0024 - val_loss: 0.0236
# Epoch 7/200
# 1020/1020 [==============================] - 1s 814us/step - loss: 0.0094 - val_loss: 0.0282
# Epoch 8/200
# 1020/1020 [==============================] - 1s 771us/step - loss: 0.0100 - val_loss: 0.0244
# Epoch 9/200
# 1020/1020 [==============================] - 1s 795us/step - loss: 0.0256 - val_loss: 0.0899
# Epoch 10/200
# 1020/1020 [==============================] - 1s 795us/step - loss: 0.0227 - val_loss: 0.0404
# Epoch 11/200
# 1020/1020 [==============================] - 1s 798us/step - loss: 0.0198 - val_loss: 0.0338
# Epoch 12/200
# 1020/1020 [==============================] - 1s 797us/step - loss: 0.0329 - val_loss: 0.0628
# Epoch 13/200
# 1020/1020 [==============================] - 1s 788us/step - loss: 0.0174 - val_loss: 0.0262
# Epoch 14/200
# 1020/1020 [==============================] - 1s 799us/step - loss: 0.0153 - val_loss: 0.0381
# Epoch 15/200
# 1020/1020 [==============================] - 1s 819us/step - loss: 0.0140 - val_loss: 0.0506
# Epoch 16/200
# 1020/1020 [==============================] - 1s 805us/step - loss: 0.0787 - val_loss: 0.0576
# Epoch 17/200
# 1020/1020 [==============================] - 1s 737us/step - loss: 0.1061 - val_loss: 0.0740
# Epoch 18/200
# 1020/1020 [==============================] - 1s 825us/step - loss: 0.0298 - val_loss: 0.0260
# Epoch 19/200
# 1020/1020 [==============================] - 1s 794us/step - loss: 0.0409 - val_loss: 0.0759
# Epoch 20/200
# 1020/1020 [==============================] - 1s 787us/step - loss: 0.0941 - val_loss: 0.0619
# Epoch 21/200
# 1020/1020 [==============================] - 1s 873us/step - loss: 0.0302 - val_loss: 0.0776
# Epoch 22/200
# 1020/1020 [==============================] - 1s 882us/step - loss: 0.0164 - val_loss: 0.0291
# Epoch 23/200
# 1020/1020 [==============================] - 1s 800us/step - loss: 0.0066 - val_loss: 0.0406
# Epoch 24/200
# 1020/1020 [==============================] - 1s 802us/step - loss: 0.0129 - val_loss: 0.0299
# Epoch 25/200
# 1020/1020 [==============================] - 1s 783us/step - loss: 0.0290 - val_loss: 0.0275
# Epoch 26/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0160 - val_loss: 0.0248
# Epoch 27/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0124 - val_loss: 0.0665
# Epoch 28/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0132 - val_loss: 0.0299
# Epoch 29/200
# 1020/1020 [==============================] - 1s 982us/step - loss: 0.0454 - val_loss: 0.0243
# Epoch 30/200
# 1020/1020 [==============================] - 1s 951us/step - loss: 0.0772 - val_loss: 0.1743
# Epoch 31/200
# 1020/1020 [==============================] - 1s 916us/step - loss: 0.1161 - val_loss: 0.0321
# Epoch 32/200
# 1020/1020 [==============================] - 1s 832us/step - loss: 0.0682 - val_loss: 0.0329
# Epoch 33/200
# 1020/1020 [==============================] - 1s 791us/step - loss: 0.0333 - val_loss: 0.0664
# Epoch 34/200
# 1020/1020 [==============================] - 1s 776us/step - loss: 0.0115 - val_loss: 0.0435
# Epoch 35/200
# 1020/1020 [==============================] - 1s 788us/step - loss: 0.0064 - val_loss: 0.0520
# Epoch 36/200
# 1020/1020 [==============================] - 1s 907us/step - loss: 0.0199 - val_loss: 0.0977
# Epoch 37/200
# 1020/1020 [==============================] - 1s 853us/step - loss: 0.0128 - val_loss: 0.0242
# Epoch 38/200
# 1020/1020 [==============================] - 1s 777us/step - loss: 0.0052 - val_loss: 0.0315
# Epoch 39/200
# 1020/1020 [==============================] - 1s 790us/step - loss: 0.0110 - val_loss: 0.0232
# Epoch 40/200
# 1020/1020 [==============================] - 1s 788us/step - loss: 0.0156 - val_loss: 0.0426
# Epoch 41/200
# 1020/1020 [==============================] - 1s 760us/step - loss: 0.0339 - val_loss: 0.0956
# Epoch 42/200
# 1020/1020 [==============================] - 1s 758us/step - loss: 0.0304 - val_loss: 0.0553
# Epoch 43/200
# 1020/1020 [==============================] - 1s 773us/step - loss: 0.0186 - val_loss: 0.0407
# Epoch 44/200
# 1020/1020 [==============================] - 1s 760us/step - loss: 0.0105 - val_loss: 0.0266
# Epoch 45/200
# 1020/1020 [==============================] - 1s 765us/step - loss: 0.0197 - val_loss: 0.0251
# Epoch 46/200
# 1020/1020 [==============================] - 1s 766us/step - loss: 0.0222 - val_loss: 0.0578
# Epoch 47/200
# 1020/1020 [==============================] - 1s 767us/step - loss: 0.0236 - val_loss: 0.0570
# Epoch 48/200
# 1020/1020 [==============================] - 1s 791us/step - loss: 0.0362 - val_loss: 0.0287
# Epoch 49/200
# 1020/1020 [==============================] - 1s 788us/step - loss: 0.0400 - val_loss: 0.0793
# Epoch 50/200
# 1020/1020 [==============================] - 1s 778us/step - loss: 0.0390 - val_loss: 0.0493
# Epoch 51/200
# 1020/1020 [==============================] - 1s 785us/step - loss: 0.0529 - val_loss: 0.0268
# Epoch 52/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0063 - val_loss: 0.0247
# Epoch 53/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0063 - val_loss: 0.0250
# Epoch 54/200
# 1020/1020 [==============================] - 1s 873us/step - loss: 0.0262 - val_loss: 0.1652
# Epoch 55/200
# 1020/1020 [==============================] - 1s 811us/step - loss: 0.0788 - val_loss: 0.2017
# Epoch 56/200
# 1020/1020 [==============================] - 1s 723us/step - loss: 0.0329 - val_loss: 0.0282
# Epoch 57/200
# 1020/1020 [==============================] - 1s 713us/step - loss: 0.0136 - val_loss: 0.0755
# Epoch 58/200
# 1020/1020 [==============================] - 1s 689us/step - loss: 0.0213 - val_loss: 0.0306
# Epoch 59/200
# 1020/1020 [==============================] - 1s 743us/step - loss: 0.0528 - val_loss: 0.0261
# Epoch 60/200
# 1020/1020 [==============================] - 1s 976us/step - loss: 0.0337 - val_loss: 0.0270
# Epoch 61/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0098 - val_loss: 0.0269
# Epoch 62/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0255 - val_loss: 0.0254
# Epoch 63/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0123 - val_loss: 0.0286
# Epoch 64/200
# 1020/1020 [==============================] - 2s 2ms/step - loss: 0.0176 - val_loss: 0.0393
# Epoch 65/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0201 - val_loss: 0.0294
# Epoch 66/200
# 1020/1020 [==============================] - 1s 969us/step - loss: 0.0142 - val_loss: 0.0379
# Epoch 67/200
# 1020/1020 [==============================] - 1s 790us/step - loss: 0.0403 - val_loss: 0.0305
# Epoch 68/200
# 1020/1020 [==============================] - 1s 877us/step - loss: 0.0979 - val_loss: 0.0756
# Epoch 69/200
# 1020/1020 [==============================] - 1s 966us/step - loss: 0.0185 - val_loss: 0.0534ETA: 0s - loss: 0.019
# Epoch 70/200
# 1020/1020 [==============================] - 1s 957us/step - loss: 0.0169 - val_loss: 0.0442
# Epoch 71/200
# 1020/1020 [==============================] - 1s 788us/step - loss: 0.0550 - val_loss: 0.0274
# Epoch 72/200
# 1020/1020 [==============================] - 1s 689us/step - loss: 0.0327 - val_loss: 0.1668
# Epoch 73/200
# 1020/1020 [==============================] - 1s 698us/step - loss: 0.0479 - val_loss: 0.0377
# Epoch 74/200
# 1020/1020 [==============================] - 1s 801us/step - loss: 0.0220 - val_loss: 0.0265
# Epoch 75/200
# 1020/1020 [==============================] - 1s 788us/step - loss: 0.0070 - val_loss: 0.0270
# Epoch 76/200
# 1020/1020 [==============================] - 1s 947us/step - loss: 0.0075 - val_loss: 0.0327
# Epoch 77/200
# 1020/1020 [==============================] - 1s 786us/step - loss: 0.0261 - val_loss: 0.0416
# Epoch 78/200
# 1020/1020 [==============================] - 1s 956us/step - loss: 0.0137 - val_loss: 0.0280
# Epoch 79/200
# 1020/1020 [==============================] - 1s 707us/step - loss: 0.0253 - val_loss: 0.0283
# Epoch 80/200
# 1020/1020 [==============================] - 1s 771us/step - loss: 0.0220 - val_loss: 0.0253
# Epoch 81/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0575 - val_loss: 0.0278
# Epoch 82/200
# 1020/1020 [==============================] - 1s 793us/step - loss: 0.0435 - val_loss: 0.0430
# Epoch 83/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0293 - val_loss: 0.0542
# Epoch 84/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0334 - val_loss: 0.0336
# Epoch 85/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0337 - val_loss: 0.0310
# Epoch 86/200
# 1020/1020 [==============================] - 1s 963us/step - loss: 0.0349 - val_loss: 0.0510
# Epoch 87/200
# 1020/1020 [==============================] - 2s 2ms/step - loss: 0.0345 - val_loss: 0.0281
# Epoch 88/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0097 - val_loss: 0.0248
# Epoch 89/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0075 - val_loss: 0.0352
# Epoch 90/200
# 1020/1020 [==============================] - 1s 994us/step - loss: 0.0116 - val_loss: 0.0250
# Epoch 91/200
# 1020/1020 [==============================] - 1s 789us/step - loss: 0.0119 - val_loss: 0.0247
# Epoch 92/200
# 1020/1020 [==============================] - 1s 863us/step - loss: 0.0276 - val_loss: 0.2777
# Epoch 93/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0903 - val_loss: 0.1133
# Epoch 94/200
# 1020/1020 [==============================] - 1s 830us/step - loss: 0.0339 - val_loss: 0.0313
# Epoch 95/200
# 1020/1020 [==============================] - 1s 953us/step - loss: 0.0167 - val_loss: 0.0267
# Epoch 96/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0166 - val_loss: 0.0263
# Epoch 97/200
# 1020/1020 [==============================] - 1s 708us/step - loss: 0.0481 - val_loss: 0.0271
# Epoch 98/200
# 1020/1020 [==============================] - 1s 926us/step - loss: 0.0147 - val_loss: 0.1164
# Epoch 99/200
# 1020/1020 [==============================] - 1s 712us/step - loss: 0.0255 - val_loss: 0.0655
# Epoch 100/200
# 1020/1020 [==============================] - 1s 749us/step - loss: 0.0586 - val_loss: 0.1210
# Epoch 101/200
# 1020/1020 [==============================] - 1s 855us/step - loss: 0.0539 - val_loss: 0.0289
# Epoch 102/200
# 1020/1020 [==============================] - 1s 855us/step - loss: 0.0073 - val_loss: 0.0308
# Epoch 103/200
# 1020/1020 [==============================] - 1s 947us/step - loss: 0.0048 - val_loss: 0.0263
# Epoch 104/200
# 1020/1020 [==============================] - 1s 881us/step - loss: 0.0135 - val_loss: 0.0552
# Epoch 105/200
# 1020/1020 [==============================] - 1s 812us/step - loss: 0.0071 - val_loss: 0.0292
# Epoch 106/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0530 - val_loss: 0.0587
# Epoch 107/200
# 1020/1020 [==============================] - 1s 911us/step - loss: 0.1972 - val_loss: 0.1170
# Epoch 108/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0554 - val_loss: 0.0568
# Epoch 109/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0118 - val_loss: 0.0449
# Epoch 110/200
# 1020/1020 [==============================] - 1s 913us/step - loss: 0.0042 - val_loss: 0.0267
# Epoch 111/200
# 1020/1020 [==============================] - 1s 856us/step - loss: 0.0047 - val_loss: 0.0222
# Epoch 112/200
# 1020/1020 [==============================] - 1s 951us/step - loss: 0.0109 - val_loss: 0.0227
# Epoch 113/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0100 - val_loss: 0.0233
# Epoch 114/200
# 1020/1020 [==============================] - 1s 886us/step - loss: 0.0025 - val_loss: 0.0240
# Epoch 115/200
# 1020/1020 [==============================] - 1s 866us/step - loss: 0.0483 - val_loss: 0.1367
# Epoch 116/200
# 1020/1020 [==============================] - 1s 896us/step - loss: 0.1450 - val_loss: 0.0411
# Epoch 117/200
# 1020/1020 [==============================] - 1s 811us/step - loss: 0.0806 - val_loss: 0.0319
# Epoch 118/200
# 1020/1020 [==============================] - 1s 873us/step - loss: 0.0343 - val_loss: 0.1579
# Epoch 119/200
# 1020/1020 [==============================] - 1s 896us/step - loss: 0.0543 - val_loss: 0.0795
# Epoch 120/200
# 1020/1020 [==============================] - 1s 927us/step - loss: 0.0149 - val_loss: 0.0339
# Epoch 121/200
# 1020/1020 [==============================] - 1s 893us/step - loss: 0.0073 - val_loss: 0.0226
# Epoch 122/200
# 1020/1020 [==============================] - 1s 826us/step - loss: 0.0034 - val_loss: 0.0231
# Epoch 123/200
# 1020/1020 [==============================] - 1s 902us/step - loss: 0.0137 - val_loss: 0.0475
# Epoch 124/200
# 1020/1020 [==============================] - 1s 863us/step - loss: 0.0160 - val_loss: 0.0327
# Epoch 125/200
# 1020/1020 [==============================] - 1s 951us/step - loss: 0.0070 - val_loss: 0.0234
# Epoch 126/200
# 1020/1020 [==============================] - 1s 767us/step - loss: 0.0047 - val_loss: 0.0245
# Epoch 127/200
# 1020/1020 [==============================] - 1s 871us/step - loss: 0.0057 - val_loss: 0.0241
# Epoch 128/200
# 1020/1020 [==============================] - 1s 907us/step - loss: 0.0026 - val_loss: 0.0227
# Epoch 129/200
# 1020/1020 [==============================] - 1s 842us/step - loss: 0.0057 - val_loss: 0.0238
# Epoch 130/200
# 1020/1020 [==============================] - 1s 909us/step - loss: 0.0057 - val_loss: 0.0401
# Epoch 131/200
# 1020/1020 [==============================] - 1s 858us/step - loss: 0.0105 - val_loss: 0.0268
# Epoch 132/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0388 - val_loss: 0.1752
# Epoch 133/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0291 - val_loss: 0.0447
# Epoch 134/200
# 1020/1020 [==============================] - 1s 974us/step - loss: 0.0250 - val_loss: 0.0239
# Epoch 135/200
# 1020/1020 [==============================] - 1s 1ms/step - loss: 0.0408 - val_loss: 0.1226
# Epoch 136/200
# 1020/1020 [==============================] - 1s 946us/step - loss: 0.0548 - val_loss: 0.0862
# Epoch 137/200
# 1020/1020 [==============================] - 1s 883us/step - loss: 0.0497 - val_loss: 0.0646
# Epoch 138/200
# 1020/1020 [==============================] - 1s 762us/step - loss: 0.0180 - val_loss: 0.0315
# Epoch 139/200
# 1020/1020 [==============================] - 1s 753us/step - loss: 0.0172 - val_loss: 0.1013
# Epoch 140/200
# 1020/1020 [==============================] - 1s 853us/step - loss: 0.0154 - val_loss: 0.0275
# Epoch 141/200
# 1020/1020 [==============================] - 1s 826us/step - loss: 0.0059 - val_loss: 0.0279
# Epoch 142/200
# 1020/1020 [==============================] - 1s 771us/step - loss: 0.0124 - val_loss: 0.0235
# Epoch 143/200
# 1020/1020 [==============================] - 1s 738us/step - loss: 0.0516 - val_loss: 0.1175
# Epoch 144/200
# 1020/1020 [==============================] - 1s 779us/step - loss: 0.0341 - val_loss: 0.0249
# Epoch 145/200
# 1020/1020 [==============================] - 1s 771us/step - loss: 0.0333 - val_loss: 0.0264
# Epoch 146/200
# 1020/1020 [==============================] - 1s 764us/step - loss: 0.0356 - val_loss: 0.0362
# Epoch 147/200
# 1020/1020 [==============================] - 1s 770us/step - loss: 0.0081 - val_loss: 0.0287
# Epoch 148/200
# 1020/1020 [==============================] - 1s 806us/step - loss: 0.0367 - val_loss: 0.1238
# Epoch 149/200
# 1020/1020 [==============================] - 1s 739us/step - loss: 0.0266 - val_loss: 0.1133
# Epoch 150/200
# 1020/1020 [==============================] - 1s 746us/step - loss: 0.0214 - val_loss: 0.0256
# Epoch 151/200
# 1020/1020 [==============================] - 1s 744us/step - loss: 0.0153 - val_loss: 0.0236
# Epoch 152/200
# 1020/1020 [==============================] - 1s 749us/step - loss: 0.0358 - val_loss: 0.0446
# Epoch 153/200
# 1020/1020 [==============================] - 1s 836us/step - loss: 0.0279 - val_loss: 0.2116
# Epoch 154/200
# 1020/1020 [==============================] - 1s 850us/step - loss: 0.0504 - val_loss: 0.0275
# Epoch 155/200
# 1020/1020 [==============================] - 1s 861us/step - loss: 0.0118 - val_loss: 0.0251
# Epoch 156/200
# 1020/1020 [==============================] - 1s 917us/step - loss: 0.0077 - val_loss: 0.0741
# Epoch 157/200
# 1020/1020 [==============================] - 1s 918us/step - loss: 0.0182 - val_loss: 0.0267
# Epoch 158/200
# 1020/1020 [==============================] - 1s 878us/step - loss: 0.0063 - val_loss: 0.0423
# Epoch 159/200
# 1020/1020 [==============================] - 1s 768us/step - loss: 0.0259 - val_loss: 0.1269
# Epoch 160/200
# 1020/1020 [==============================] - 1s 731us/step - loss: 0.0279 - val_loss: 0.0251
# Epoch 161/200
# 1020/1020 [==============================] - 1s 754us/step - loss: 0.0262 - val_loss: 0.0280
# Epoch 162/200
# 1020/1020 [==============================] - 1s 755us/step - loss: 0.0380 - val_loss: 0.1321
# Epoch 163/200
# 1020/1020 [==============================] - 1s 831us/step - loss: 0.0380 - val_loss: 0.0249
# Epoch 164/200
# 1020/1020 [==============================] - 1s 821us/step - loss: 0.0086 - val_loss: 0.0262
# Epoch 165/200
# 1020/1020 [==============================] - 1s 753us/step - loss: 0.0177 - val_loss: 0.0315
# Epoch 166/200
# 1020/1020 [==============================] - 1s 740us/step - loss: 0.0323 - val_loss: 0.0323
# Epoch 167/200
# 1020/1020 [==============================] - 1s 749us/step - loss: 0.0423 - val_loss: 0.0796
# Epoch 168/200
# 1020/1020 [==============================] - 1s 750us/step - loss: 0.0591 - val_loss: 0.0810
# Epoch 169/200
# 1020/1020 [==============================] - 1s 846us/step - loss: 0.0599 - val_loss: 0.2110
# Epoch 170/200
# 1020/1020 [==============================] - 1s 903us/step - loss: 0.0979 - val_loss: 0.0438
# Epoch 171/200
# 1020/1020 [==============================] - 1s 881us/step - loss: 0.0129 - val_loss: 0.0354
# Epoch 172/200
# 1020/1020 [==============================] - 1s 762us/step - loss: 0.0075 - val_loss: 0.0249
# Epoch 173/200
# 1020/1020 [==============================] - 1s 835us/step - loss: 0.0066 - val_loss: 0.0241
# Epoch 174/200
# 1020/1020 [==============================] - 1s 859us/step - loss: 0.0069 - val_loss: 0.0256
# Epoch 175/200
# 1020/1020 [==============================] - 1s 830us/step - loss: 0.0089 - val_loss: 0.0266
# Epoch 176/200
# 1020/1020 [==============================] - 1s 765us/step - loss: 0.0145 - val_loss: 0.0403
# Epoch 177/200
# 1020/1020 [==============================] - 1s 766us/step - loss: 0.0152 - val_loss: 0.0384
# Epoch 178/200
# 1020/1020 [==============================] - 1s 776us/step - loss: 0.0128 - val_loss: 0.0279
# Epoch 179/200
# 1020/1020 [==============================] - 1s 796us/step - loss: 0.0303 - val_loss: 0.0239
# Epoch 180/200
# 1020/1020 [==============================] - 1s 795us/step - loss: 0.0433 - val_loss: 0.0248
# Epoch 181/200
# 1020/1020 [==============================] - 1s 813us/step - loss: 0.0330 - val_loss: 0.0375
# Epoch 182/200
# 1020/1020 [==============================] - 1s 755us/step - loss: 0.0330 - val_loss: 0.1408
# Epoch 183/200
# 1020/1020 [==============================] - 1s 769us/step - loss: 0.0391 - val_loss: 0.0342
# Epoch 184/200
# 1020/1020 [==============================] - 1s 845us/step - loss: 0.0088 - val_loss: 0.0422
# Epoch 185/200
# 1020/1020 [==============================] - 1s 867us/step - loss: 0.0170 - val_loss: 0.0345
# Epoch 186/200
# 1020/1020 [==============================] - 1s 892us/step - loss: 0.0119 - val_loss: 0.0579
# Epoch 187/200
# 1020/1020 [==============================] - 1s 859us/step - loss: 0.0393 - val_loss: 0.0667
# Epoch 188/200
# 1020/1020 [==============================] - 1s 872us/step - loss: 0.0228 - val_loss: 0.0586
# Epoch 189/200
# 1020/1020 [==============================] - 1s 849us/step - loss: 0.0191 - val_loss: 0.0318
# Epoch 190/200
# 1020/1020 [==============================] - 1s 882us/step - loss: 0.0116 - val_loss: 0.0255
# Epoch 191/200
# 1020/1020 [==============================] - 1s 824us/step - loss: 0.0135 - val_loss: 0.1021
# Epoch 192/200
# 1020/1020 [==============================] - 1s 855us/step - loss: 0.0272 - val_loss: 0.0232
# Epoch 193/200
# 1020/1020 [==============================] - 1s 852us/step - loss: 0.0452 - val_loss: 0.0990
# Epoch 194/200
# 1020/1020 [==============================] - 1s 894us/step - loss: 0.0325 - val_loss: 0.0278
# Epoch 195/200
# 1020/1020 [==============================] - 1s 850us/step - loss: 0.0265 - val_loss: 0.0357
# Epoch 196/200
# 1020/1020 [==============================] - 1s 767us/step - loss: 0.0144 - val_loss: 0.0312
# Epoch 197/200
# 1020/1020 [==============================] - 1s 782us/step - loss: 0.0164 - val_loss: 0.0368
# Epoch 198/200
# 1020/1020 [==============================] - 1s 816us/step - loss: 0.0288 - val_loss: 0.0309
# Epoch 199/200
# 1020/1020 [==============================] - 1s 832us/step - loss: 0.0675 - val_loss: 0.0292
# Epoch 200/200
# 1020/1020 [==============================] - 1s 830us/step - loss: 0.0365 - val_loss: 0.0372

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
np.shape(kerasModel.predict(X_test))
# Out:
# (1459,)

# %%
np.shape(test.Id)

kerasModel.predict(X_test)

res=np.expm1(kerasModel.predict(test_X))

# %%
np.shape(test['Id'])
# Out:
# (1459,)

# %%
solution = pd.DataFrame({"id":test['Id'], "SalePrice":res[:,0]}, columns=['id', 'SalePrice'])
solution.to_csv("result.csv", index = False)

# %%
pred_xgb=model_xgb.predict(test_X)
sol=np.expm1(pred_xgb)

solution = pd.DataFrame({"id":test['Id'], "SalePrice":lasso_preds}, columns=['id', 'SalePrice'])
solution.to_csv("result.csv", index = False)

# %%
lasso_preds
# Out:
# array([116672.85921358, 164624.28738499, 180802.60358362, ...,
#        165492.48298762, 116194.74934614, 215246.94362455])

# %% [markdown]
# ### Results

# %% [markdown]
# [4] The result suggests that ~ shows best performance .... between other method
#
# (-Create table and show the result// Leader bord score.)

# %% [markdown]
# ### Limitation/Recommendations

# %% [markdown]
# [5] Limitations/Recommendations
# 1. The training data and test dataset have a same length and the performance of the model might be improved that if we can obtain more dataset
#
# 2. We realize that a lot of domain knowledg is requried
#
# 3. Feature enginnering/ other types of model is required

# %% [markdown]
# ### Conclusion

# %% [markdown]
# [6] Fidings from EDA- Which feature was included.. how we engineerined. Model fitting and validity of model tracking down. Our efforts to try to improve the performance.

# %% [markdown]
# ### Reference/Resource

# %% [markdown]
# [1] https://www.kaggle.com/juliencs/a-study-on-regression-applied-to-the-ames-dataset

# %% [markdown]
# [2] https://github.com/Sooyeong/CSE627_project
